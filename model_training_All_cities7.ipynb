# %% [markdown]
# <a href="https://colab.research.google.com/github/mathu3004/Pearl_Path/blob/E_Personalized_Itinerary_Generator/model_training_All_cities7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import re



drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ---------------------------- #
# Step 1: Load Datasets
# ---------------------------- #

user_inputs = pd.read_excel('/content/drive/MyDrive/DSGP_ME/MergedDatasets/user_inputs_preprocessed.xlsx')
Hotels = pd.read_csv('/content/drive/MyDrive/DSGP_ME/MergedDatasets/ProcessedHotels.csv')
Restaurants = pd.read_csv('/content/drive/MyDrive/DSGP_ME/MergedDatasets/PreprocessedRestaurants.csv')
Attractions = pd.read_excel('/content/drive/MyDrive/DSGP_ME/MergedDatasets/attractions_preprocessed.xlsx')

# ---------------------------- #
# Step 2: Clean Column Names (Remove Spaces)
# ---------------------------- #
def clean_column_names(df):
    df.columns = [col.replace(' ', '_') for col in df.columns]
    return df

user_inputs = clean_column_names(user_inputs)
Hotels = clean_column_names(Hotels)
Restaurants = clean_column_names(Restaurants)
Attractions = clean_column_names(Attractions)

# ---------------------------- #
# Step 3: Encoding Destinations, Cuisines, Amenities, and Dietary Preferences
# ---------------------------- #

# Allowed destinations
allowed_destinations = {'Kandy', 'Ella', 'Colombo', 'Nuwara Eliya'}

# Encode destinations
all_destinations = set()
for dest in user_inputs['destination'].dropna():
    all_destinations.update(dest.split(', '))
destination_encoder = {dest: idx + 1 for idx, dest in enumerate(sorted(all_destinations)) if dest in allowed_destinations}

def encode_destinations(destination_str):
    return [destination_encoder.get(dest.strip()) for dest in destination_str.split(', ') if dest.strip() in destination_encoder]

user_inputs['encoded_destination'] = user_inputs['destination'].apply(encode_destinations)

# Encode cuisines in restaurants
all_cuisines = set()
for cuisines in Restaurants['cuisines'].dropna():
    all_cuisines.update(cuisines.split(', '))
cuisine_encoder = {cuisine: idx + 1 for idx, cuisine in enumerate(sorted(all_cuisines))}

# Encode amenities in hotels
all_amenities = set()
for amenities in Hotels['all_amenities'].dropna():
    all_amenities.update(amenities.split(', '))
amenity_encoder = {amenity: idx + 1 for idx, amenity in enumerate(sorted(all_amenities))}

# Encode dietary restrictions in restaurants
veg_friendly = {'Vegetarian friendly', 'Vegan options', 'Halal', 'Gluten free options'}
non_veg_friendly = {'No Special Dietary'}

def encode_dietary_restrictions(dietary_str):
    if pd.isna(dietary_str):
        return set()
    restrictions = set(dietary_str.split(', '))
    if restrictions & veg_friendly:
        return {1}  # Veg
    elif restrictions & non_veg_friendly:
        return {3}  # Non-Veg
    return set()

Restaurants['encoded_dietaryrestrictions'] = Restaurants['dietaryrestrictions'].apply(encode_dietary_restrictions)

# Apply encoding
Restaurants['encoded_cuisines'] = Restaurants['cuisines'].apply(lambda x: {cuisine_encoder[c] for c in x.split(', ')} if pd.notna(x) else set())
Hotels['encoded_amenities'] = Hotels['all_amenities'].apply(lambda x: {amenity_encoder[a] for a in x.split(', ')} if pd.notna(x) else set())

# Encode user's food preference
food_preference_encoder = {'Veg': 1, 'Non-Veg': 3}
user_inputs['encoded_food_preference'] = user_inputs['food_preference'].map(food_preference_encoder)

# ---------------------------- #
# Step 4: Extract City Information
# ---------------------------- #
def extract_city(address):
    match = re.search(r'([A-Za-z ]+),? Sri Lanka', str(address))
    return match.group(1).strip() if match else None

Hotels['extracted_city'] = Hotels['address'].apply(extract_city)

# ---------------------------- #
# Step 5: Matching Functions
# ---------------------------- #
def match_best_hotels(user_budget, user_destination, hotels_df):
    hotels_in_city = hotels_df[hotels_df['extracted_city'] == user_destination]
    return hotels_in_city.sort_values(by=['rating', 'rankingposition'], ascending=[False, True])

def match_best_restaurants(user_cuisine_pref, user_food_pref, user_destination, restaurants_df):
    if user_destination not in allowed_destinations:
        return pd.DataFrame()
    restaurants_in_city = restaurants_df[restaurants_df['addressobj_city'] == user_destination].copy()
    user_encoded_cuisines = {cuisine_encoder.get(c, 0) for c in user_cuisine_pref.split(', ') if c in cuisine_encoder}
    user_encoded_food_pref = food_preference_encoder.get(user_food_pref, 3)

    def calculate_match_score(row):
        cuisine_score = len(user_encoded_cuisines.intersection(row['encoded_cuisines']))
        dietary_score = int(user_encoded_food_pref in row['encoded_dietaryrestrictions'])
        return cuisine_score + dietary_score

    restaurants_in_city['match_score'] = restaurants_in_city.apply(calculate_match_score, axis=1)
    return restaurants_in_city.sort_values(by='match_score', ascending=False)

def match_best_attractions(user_budget, user_destination, attractions_df):
    if user_destination not in allowed_destinations:
        return pd.DataFrame()
    attractions_in_city = attractions_df[(attractions_df['City'] == user_destination) & (attractions_df['Lowest_Price'] <= user_budget)]
    return attractions_in_city.sort_values(by=['Rating', 'Ranking_Position'], ascending=[False, True])

# ---------------------------- #
# Step 6: Generate Itinerary
# ---------------------------- #

for index, user in user_inputs.iterrows():
    destinations = user['destination'].split(', ')
    num_days = user['number_of_days']
    selected_destinations = destinations[:2] if num_days >= 4 else [destinations[0]]

    print(f"\n===== User {index + 1}: {user['name']} =====")
    print(f"Destination: {', '.join(selected_destinations)}")
    print(f"Cuisine Preference: {user['cuisine_preference']}")
    print(f"Food Preference: {user['food_preference']}")
    print(f"Budget Per Day: {user['budget_per_day']}")

    for day in range(num_days):
        current_destination = selected_destinations[min(day // 2, len(selected_destinations) - 1)]
        recommended_hotels = match_best_hotels(user['budget_per_day'], current_destination, Hotels)
        recommended_restaurants = match_best_restaurants(user['cuisine_preference'], user['food_preference'], current_destination, Restaurants)
        recommended_attractions = match_best_attractions(user['budget_per_day'], current_destination, Attractions)

        if recommended_hotels.empty:
            print("No hotels found for the selected destination and budget.")
            continue  # Skip to the next user

        # Change the hotel every 3 days within a destination
        hotel = recommended_hotels.iloc[(day // 3) % len(recommended_hotels)]


        breakfast_restaurant = recommended_restaurants.iloc[day % len(recommended_restaurants)]
        attraction_1 = recommended_attractions.iloc[day % len(recommended_attractions)]
        lunch_restaurant = recommended_restaurants.iloc[(day + 1) % len(recommended_restaurants)]
        attraction_2 = recommended_attractions.iloc[(day + 1) % len(recommended_attractions)]
        dinner_restaurant = recommended_restaurants.iloc[(day + 2) % len(recommended_restaurants)]

        print(f"\nDay {day + 1} - {current_destination}")
        print(f"Hotel: {hotel['name']} (Rating: {hotel['rating']})")
        print(f"Breakfast: {breakfast_restaurant['name']} (Cuisines: {breakfast_restaurant['cuisines']})")
        print(f"Attraction 1: {attraction_1['Name']} (Lowest Price: {attraction_1['Lowest_Price']})")
        print(f"Lunch: {lunch_restaurant['name']} (Cuisines: {lunch_restaurant['cuisines']})")
        print(f"Attraction 2: {attraction_2['Name']} (Lowest Price: {attraction_2['Lowest_Price']})")
        print(f"Dinner: {dinner_restaurant['name']} (Cuisines: {dinner_restaurant['cuisines']})")
        print("Returning to Hotel\n")
        print("-" * 40)
# Out:
# Streaming output truncated to the last 5000 lines.
# Attraction 2: Honey Bee Garden (Lowest Price: No price mentioned)
# Dinner: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Honey Bee Garden (Lowest Price: No price mentioned)
# Lunch: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 2: Priya Cookery Class (Lowest Price: No price mentioned)
# Dinner: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 1: Priya Cookery Class (Lowest Price: No price mentioned)
# Lunch: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Ella Taxi Ceylon (Lowest Price: No price mentioned)
# Dinner: Cafe Ridge (Cuisines: Indian, Southwestern, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Ella Taxi Ceylon (Lowest Price: No price mentioned)
# Lunch: Cafe Ridge (Cuisines: Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Ravana Odyssey | Ella Hop-On Open Deck Double Decker Sightseeing Bus Tour (Lowest Price: LKR 78.63)
# Dinner: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 211: Chirath Setunge =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Chinese, Italian, Western, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 25000+
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: MARINATE (Cuisines: Italian, Chinese, American, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: The Chef Corner & Vip Lounge By Sugath (Cuisines: Italian, Chinese, Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast
Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 214: Rajkumer Hemachandran🎵🎵🎵 =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Cafe KOI Coffee (Cuisines: Cafe, European, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: Oak Ray Bakers (Cuisines: Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Oak Ray Bakers (Cuisines: Asian, Sri Lankan)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Attraction 1: Lanka Budget Tours (Lowest Price: No price mentioned)
# Lunch: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Palitha peiris (Lowest Price: No price mentioned)
# Dinner: Kandy Supreme Hotel (Cuisines: Chinese, European, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Palitha peiris (Lowest Price: No price mentioned)
# Lunch: Kandy Supreme Hotel (Cuisines: Chinese, European, Asian, Sri Lankan)
# Attraction 2: SL Tuk Tuk Travels (Lowest Price: $0.12)
# Dinner: Mymomo (Cuisines: Chinese, Cafe, Asian, Korean, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 215: Bhagya Silva =====
# Destination: Nuwara Eliya
# Cuisine Preference: Italian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 20500 - Rs. 24500
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Royal Wok Restaurant (Cuisines: Italian, French, Chinese, Cafe)
# Attraction 1: DS Kumar Tuktuk Sightseeing in Nuwara Eliya (Lowest Price: No price mentioned)
# Lunch: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: nitwo tours (Lowest Price: No price mentioned)
# Dinner: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: nitwo tours (Lowest Price: No price mentioned)
# Lunch: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 2: Roll Trips Tours (Lowest Price: No price mentioned)
# Dinner: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 1: Roll Trips Tours (Lowest Price: No price mentioned)
# Lunch: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Dinner: Salmiya (Cuisines: Italian, Pizza)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Lunch: Salmiya (Cuisines: Italian, Pizza)
# Attraction 2: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Dinner: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 216: Subajini =====
# Destination: Kandy, Dambulla
# Cuisine Preference: Sri Lankan, Indian, Italian
# Food Preference: Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Mystery Meat (Cuisines: Italian, International, Asian, Korean, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: Sri Ganeshananda Brahmins Vegetarian Hotel (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Kurumbunkz (Cuisines: Italian, American, Asian, Australian, Indonesian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Sri Ganeshananda Brahmins Vegetarian Hotel (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: Kurumbunkz (Cuisines: Italian, American, Asian, Australian, Indonesian, Sri Lankan)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: Nishantha Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
#
# ===== User 217: Atheeq Ahamed  =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Madhavan's spicy food kandy (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Avanhala (Cuisines: Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: Avanhala (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Avanhala (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Lanka Budget Tours (Lowest Price: No price mentioned)
# Lunch: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Attraction 2: Palitha peiris (Lowest Price: No price mentioned)
# Dinner: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 218: Sharon =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Cafe KOI Coffee (Cuisines: Cafe, European, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: Oak Ray Bakers (Cuisines: Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Oak Ray Bakers (Cuisines: Asian, Sri Lankan)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Senkin Restaurant (Cuisines: Asian, Sri Lankan)
# Attraction 1: R. M. S Antique And Brassware (Lowest Price: No price mentioned)
# Lunch: Lakshmi's Cookery Class (Cuisines: Asian, Sri Lankan)
# Attraction 2: Honey Bee Garden (Lowest Price: No price mentioned)
# Dinner: Ramesh Restaurant (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: Lakshmi's Cookery Class (Cuisines: Asian, Sri Lankan)
# Attraction 1: Honey Bee Garden (Lowest Price: No price mentioned)
# Lunch: Ramesh Restaurant (Cuisines: Asian, Sri Lankan)
# Attraction 2: Priya Cookery Class (Lowest Price: No price mentioned)
# Dinner: Mum Cafe And Restaurant Ella (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 219: Thasheera =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 20500 - Rs. 24500
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Fab Ceylon Grand (Cuisines: Italian, Chinese, American, Indian, Cafe)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: Fab Ceylon Grand (Cuisines: Italian, Chinese, American, Indian, Cafe)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: Brix (Cuisines: Chinese, Indian, Asian, Thai, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Fab Ceylon Grand (Cuisines: Italian, Chinese, American, Indian, Cafe)
# Attraction 1: Lanka Budget Tours (Lowest Price: No price mentioned)
# Lunch: Brix (Cuisines: Chinese, Indian, Asian, Thai, Arabic)
# Attraction 2: Palitha peiris (Lowest Price: No price mentioned)
# Dinner: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 220: Wayne =====
# Destination: Kandy
# Cuisine Preference: Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: Lion Brand Coffee & Bakery (Cuisines: Italian, Mexican, American, Cafe, Asian, Thai, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Lemon Grass Thai Restaurant - The Grand Kandyan Hotel (Cuisines: Thai)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 221: Kugan Vicknes =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Mexican
# Food Preference: Veg
# Budget Per Day: Rs. 25000+
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Green View Restaurant (Cuisines: Chinese, Indian, Asian, Soups, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Lion Brand Coffee & Bakery (Cuisines: Italian, Mexican, American, Cafe, Asian, Thai, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: Lion Brand Coffee & Bakery (Cuisines: Italian, Mexican, American, Cafe, Asian, Thai, Sri Lankan)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: The Empire Cafe (Cuisines: Chinese, Indian, European, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Lion Brand Coffee & Bakery (Cuisines: Italian, Mexican, American, Cafe, Asian, Thai, Sri Lankan)
# Attraction 1: Lanka Budget Tours (Lowest Price: No price mentioned)
# Lunch: The Empire Cafe (Cuisines: Chinese, Indian, European, Sri Lankan)
# Attraction 2: Palitha peiris (Lowest Price: No price mentioned)
# Dinner: Nishantha Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 222: Kandasamy  Sumanan =====
# Destination: Kandy, Ella
# Cuisine Preference: Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 20500 - Rs. 24500
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Global Kitchens (Cuisines: Steakhouse, Indian, International, Asian, Street Food, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast:
- Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Oak Ray Bakers (Cuisines: Asian, Sri Lankan)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Senkin Restaurant (Cuisines: Asian, Sri Lankan)
# Attraction 1: R. M. S Antique And Brassware (Lowest Price: No price mentioned)
# Lunch: Lakshmi's Cookery Class (Cuisines: Asian, Sri Lankan)
# Attraction 2: Honey Bee Garden (Lowest Price: No price mentioned)
# Dinner: Ramesh Restaurant (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: Lakshmi's Cookery Class (Cuisines: Asian, Sri Lankan)
# Attraction 1: Honey Bee Garden (Lowest Price: No price mentioned)
# Lunch: Ramesh Restaurant (Cuisines: Asian, Sri Lankan)
# Attraction 2: Priya Cookery Class (Lowest Price: No price mentioned)
# Dinner: Mum Cafe And Restaurant Ella (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 225: Devuja =====
# Destination: Ella
# Cuisine Preference: Sri Lankan, Chinese, Italian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Dream Club Ella (Lowest Price: No price mentioned)
# Lunch: Ella's Edge Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Ella Holidays (Lowest Price: LKR 116.48)
# Dinner: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Ella's Edge Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Ella Holidays (Lowest Price: LKR 116.48)
# Lunch: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: R. M. S Antique And Brassware (Lowest Price: No price mentioned)
# Dinner: Pub Ceylon Ella (Cuisines: Italian, International, Asian, Grill, Healthy, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: R. M. S Antique And Brassware (Lowest Price: No price mentioned)
# Lunch: Pub Ceylon Ella (Cuisines: Italian, International, Asian, Grill, Healthy, Sri Lankan)
# Attraction 2: Honey Bee Garden (Lowest Price: No price mentioned)
# Dinner: Rawan Adams Resturent (Cuisines: Chinese, European, Asian, Central European, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 226: Amaya Mandakshi =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: DS Kumar Tuktuk Sightseeing in Nuwara Eliya (Lowest Price: No price mentioned)
# Lunch: La Cottage Boutique Hotel & Restuarant (Cuisines: Chinese, Indian, European, Asian, Sri Lankan, Arabic)
# Attraction 2: nitwo tours (Lowest Price: No price mentioned)
# Dinner: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: La Cottage Boutique Hotel & Restuarant (Cuisines: Chinese, Indian, European, Asian, Sri Lankan, Arabic)
# Attraction 1: nitwo tours (Lowest Price: No price mentioned)
# Lunch: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 2: Roll Trips Tours (Lowest Price: No price mentioned)
# Dinner: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 1: Roll Trips Tours (Lowest Price: No price mentioned)
# Lunch: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 2: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Dinner: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 227: A. Sithika Jayawickrama =====
# Destination: Ella
# Cuisine Preference: Sri Lankan, Italian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Dream Club Ella (Lowest Price: No price mentioned)
# Lunch: Nature life guest inn Ella Sri Lanka (Cuisines: Italian, American, Indian, Filipino, Asian, Sri Lankan)
# Attraction 2: Ella Holidays (Lowest Price: LKR 116.48)
# Dinner: Pub Ceylon Ella (Cuisines: Italian, International, Asian, Grill, Healthy, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Nature life guest inn Ella Sri Lanka (Cuisines: Italian, American, Indian, Filipino, Asian, Sri Lankan)
# Attraction 1: Ella Holidays (Lowest Price: LKR 116.48)
# Lunch: Pub Ceylon Ella (Cuisines: Italian, International, Asian, Grill, Healthy, Sri Lankan)
# Attraction 2: R. M. S Antique And Brassware (Lowest Price: No price mentioned)
# Dinner: Cafe A Lounge (Cuisines: Italian, Cafe, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Pub Ceylon Ella (Cuisines: Italian, International, Asian, Grill, Healthy, Sri Lankan)
# Attraction 1: R. M. S Antique And Brassware (Lowest Price: No price mentioned)
# Lunch: Cafe A Lounge (Cuisines: Italian, Cafe, Asian, Sri Lankan)
# Attraction 2: Honey Bee Garden (Lowest Price: No price mentioned)
# Dinner: Avocado Cafe Ella (Cuisines: Italian, Mexican, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User

# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 1: Roll Trips Tours (Lowest Price: No price mentioned)
# Lunch: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Dinner: Salmiya (Cuisines: Italian, Pizza)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Lunch: Salmiya (Cuisines: Italian, Pizza)
# Attraction 2: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Dinner: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 230: Samith =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Chinese
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Manna (Cuisines: Chinese, Asian, Indonesian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: Cafe Seema (Cuisines: Chinese, Southwestern, Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Kandyan Rice and Curry (Cuisines: Chinese, Cafe, Seafood, Fast Food, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Cafe Seema (Cuisines: Chinese, Southwestern, Asian, Sri Lankan)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: Kandyan Rice and Curry (Cuisines: Chinese, Cafe, Seafood, Fast Food, Asian, Sri Lankan)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: Downtown Cafe (Cuisines: Chinese, American, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Kandyan Rice and Curry (Cuisines: Chinese, Cafe, Seafood, Fast Food, Asian, Sri Lankan)
# Attraction 1: Lanka Budget Tours (Lowest Price: No price mentioned)
# Lunch: Downtown Cafe (Cuisines: Chinese, American, Asian, Sri Lankan)
# Attraction 2: Palitha peiris (Lowest Price: No price mentioned)
# Dinner: MARINATE (Cuisines: Italian, Chinese, American, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 231: Fathima =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian, Italian
# Food Preference: Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Mystery Meat (Cuisines: Italian, International, Asian, Korean, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: Sri Ganeshananda Brahmins Vegetarian Hotel (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Kurumbunkz (Cuisines: Italian, American, Asian, Australian, Indonesian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast:
Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 233: D. Senanayake =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Fab Ceylon Grand (Cuisines: Italian, Chinese, American, Indian, Cafe)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: Fab Ceylon Grand (Cuisines: Italian, Chinese, American, Indian, Cafe)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: Brix (Cuisines: Chinese, Indian, Asian, Thai, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Fab Ceylon Grand (Cuisines: Italian, Chinese, American, Indian, Cafe)
# Attraction 1: Lanka Budget Tours (Lowest Price: No price mentioned)
# Lunch: Brix (Cuisines: Chinese, Indian, Asian, Thai, Arabic)
# Attraction 2: Palitha peiris (Lowest Price: No price mentioned)
# Dinner: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 234: Lumini =====
# Destination: Ella
# Cuisine Preference: Sri Lankan, Indian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
#
# Day 1 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Ice Mango Ella (Cuisines: Indian, Seafood, European, Asian, Street Food, Sri Lankan)
# Attraction 1: Dream Club Ella (Lowest Price: No price mentioned)
# Lunch: Singhe restaurant (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Ella Holidays (Lowest Price: LKR 116.48)
# Dinner: Nature life guest inn Ella Sri Lanka (Cuisines: Italian, American, Indian, Filipino, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Singhe restaurant (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Ella Holidays (Lowest Price: LKR 116.48)
# Lunch: Nature life guest inn Ella Sri Lanka (Cuisines: Italian, American, Indian, Filipino, Asian, Sri Lankan)
# Attraction 2: R. M. S Antique And Brassware (Lowest Price: No price mentioned)
# Dinner: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Nature life guest inn Ella Sri Lanka (Cuisines: Italian, American, Indian, Filipino, Asian, Sri Lankan)
# Attraction 1: R. M. S Antique And Brassware (Lowest Price: No price mentioned)
# Lunch: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Honey Bee Garden (Lowest Price: No price mentioned)
# Dinner: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 235: Chanmini =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Fab Ceylon Grand (Cuisines: Italian, Chinese, American, Indian, Cafe)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: The Vinci Cafe (Cuisines: Italian, Chinese, Indian, International, Asian, Sri Lankan)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: Fab Ceylon Grand (Cuisines: Italian, Chinese, American, Indian, Cafe)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: Brix (Cuisines: Chinese, Indian, Asian, Thai, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Fab Ceylon Grand (Cuisines: Italian, Chinese, American, Indian, Cafe)
# Attraction 1: Lanka Budget Tours (Lowest Price: No price mentioned)
# Lunch: Brix (Cuisines: Chinese, Indian, Asian, Thai, Arabic)
# Attraction 2: Palitha peiris (Lowest Price: No price mentioned)
# Dinner: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 236: Piyumini  =====
# Destination: Nuwara Eliya
# Cuisine Preference: Indian
# Food Preference: Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Grand Indian (Cuisines: Indian, Asian)
# Attraction 1: DS Kumar Tuktuk Sightseeing in Nuwara Eliya (Lowest Price: No price mentioned)
# Lunch: Sri Ambaal (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: nitwo tours (Lowest Price: No price mentioned)
# Dinner: Queenswood Restaurant (Cuisines: Chinese, Indian, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Sri Ambaal (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: nitwo tours (Lowest Price: No price mentioned)
# Lunch: Queenswood Restaurant (Cuisines: Chinese, Indian, Arabic)
# Attraction 2: Roll Trips Tours (Lowest Price: No price mentioned)
# Dinner: Araliya Green City Food Court (Cuisines: Indian, Cafe, Asian, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# ...
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 318: S.D.Perera =====
# Destination: Ella, Nuwara Eliya
# Cuisine Preference: Sri Lankan, Chinese
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Dream Club Ella (Lowest Price: No price mentioned)
# Lunch: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Ella Holidays (Lowest Price: LKR 116.48)
# Dinner: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Ella Holidays (Lowest Price: LKR 116.48)
# Lunch: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: R. M. S Antique And Brassware (Lowest Price: No price mentioned)
# Dinner: Rawan Adams Resturent (Cuisines: Chinese, European, Asian, Central European, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 1: Roll Trips Tours (Lowest Price: No price mentioned)
# Lunch: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Dinner: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Lunch: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Dinner: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Lunch: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Sri Lanka Magical Tours (Lowest Price: No price mentioned)
# Dinner: Gregory Green Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Sri Lanka Magical Tours (Lowest Price: No price mentioned)
# Lunch: Gregory Green Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Sri Lanka Magical Tours (Lowest Price: No price mentioned)
# Dinner: Natural View Point & Restaurant (Cuisines: Chinese, Indian, Southwestern, European, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: National Holiday Resort (Rating: 3.5)
# Breakfast: Gregory Green Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Sri Lanka Magical Tours (Lowest Price: No price mentioned)
# Lunch: Natural View Point & Restaurant (Cuisines: Chinese, Indian, Southwestern, European, Asian, Sri Lankan)
# Attraction 2: Best Journey (Lowest Price: No price mentioned)
# Dinner: Club Trout (Cuisines: Chinese, Dutch, Southwestern, European, Asian, Middle Eastern, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 319: Sanuki Waduge  =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Chinese, Italian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast:
Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Avanhala (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Lanka Budget Tours (Lowest Price: No price mentioned)
# Lunch: Madhavan's spicy food kandy (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Palitha peiris (Lowest Price: No price mentioned)
# Dinner: MARINATE (Cuisines: Italian, Chinese, American, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 321: Sahi =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Attraction 1: DS Kumar Tuktuk Sightseeing in Nuwara Eliya (Lowest Price: No price mentioned)
# Lunch: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 2: nitwo tours (Lowest Price: No price mentioned)
# Dinner: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 1: nitwo tours (Lowest Price: No price mentioned)
# Lunch: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 2: Roll Trips Tours (Lowest Price: No price mentioned)
# Dinner: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 1: Roll Trips Tours (Lowest Price: No price mentioned)
# Lunch: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 2: Horizon Tours Sri Lanka (Lowest Price: No price mentioned)
# Dinner: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 322: Neelia maha oluwa =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Veg
# Budget Per Day: Rs. 25000+
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Lion Brand Coffee & Bakery (Cuisines: Italian, Mexican, American, Cafe, Asian, Thai, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: Nishantha Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day
- Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: The Blizz Cafe (Cuisines: Italian, Chinese, Cafe, Asian, Soups)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: MARINATE (Cuisines: Italian, Chinese, American, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: The Blizz Cafe (Cuisines: Italian, Chinese, Cafe, Asian, Soups)
# Attraction 1: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Lunch: MARINATE (Cuisines: Italian, Chinese, American, Asian, Sri Lankan)
# Attraction 2: Lanka Budget Tours (Lowest Price: No price mentioned)
# Dinner: The Chef Corner & Vip Lounge By Sugath (Cuisines: Italian, Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: MARINATE (Cuisines: Italian, Chinese, American, Asian, Sri Lankan)
# Attraction 1: Lanka Budget Tours (Lowest Price: No price mentioned)
# Lunch: The Chef Corner & Vip Lounge By Sugath (Cuisines: Italian, Chinese, Asian, Sri Lankan)
# Attraction 2: Palitha peiris (Lowest Price: No price mentioned)
# Dinner: Lobster Arena (Cuisines: Italian, Chinese, Cafe, Seafood, Healthy)
# Returning to Hotel
#
# ----------------------------------------

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import MultiLabelBinarizer, LabelEncoder
from sklearn.neighbors import NearestNeighbors

# ---------------------------- #
# Step 1: Load Datasets
# ---------------------------- #

user_inputs = pd.read_excel('/content/drive/MyDrive/DSGP_ME/MergedDatasets/user_inputs_preprocessed.xlsx')
Hotels = pd.read_csv('/content/drive/MyDrive/DSGP_ME/MergedDatasets/ProcessedHotels.csv')
Restaurants = pd.read_csv('/content/drive/MyDrive/DSGP_ME/MergedDatasets/PreprocessedRestaurants.csv')
Attractions = pd.read_excel('/content/drive/MyDrive/DSGP_ME/MergedDatasets/attractions_preprocessed.xlsx')

# ---------------------------- #
# Step 2: Clean Column Names (Remove Spaces)
# ---------------------------- #
def clean_column_names(df):
    df.columns = [col.replace(' ', '_') for col in df.columns]
    return df

user_inputs = clean_column_names(user_inputs)
Hotels = clean_column_names(Hotels)
Restaurants = clean_column_names(Restaurants)
Attractions = clean_column_names(Attractions)

# ---------------------------- #
# Step 3: Encoding Destinations, Cuisines, Amenities, and Dietary Preferences
# ---------------------------- #

# Allowed destinations
allowed_destinations = {'Kandy', 'Ella', 'Colombo', 'Nuwara Eliya'}

# Encode destinations
destination_encoder = {dest: idx + 1 for idx, dest in enumerate(sorted(allowed_destinations))}

def encode_destinations(destination_str):
    return [destination_encoder.get(dest.strip(), 0) for dest in destination_str.split(', ') if dest.strip() in destination_encoder]

user_inputs['encoded_destination'] = user_inputs['destination'].apply(encode_destinations)

# Encode cuisines in restaurants
all_cuisines = set()
for cuisines in Restaurants['cuisines'].dropna():
    all_cuisines.update(cuisines.split(', '))
cuisine_encoder = {cuisine: idx + 1 for idx, cuisine in enumerate(sorted(all_cuisines))}

# Encode amenities in hotels
all_amenities = set()
for amenities in Hotels['all_amenities'].dropna():
    all_amenities.update(amenities.split(', '))
amenity_encoder = {amenity: idx + 1 for idx, amenity in enumerate(sorted(all_amenities))}

# Encode dietary restrictions in restaurants
veg_friendly = {'Vegetarian friendly', 'Vegan options', 'Halal', 'Gluten free options'}
non_veg_friendly = {'No Special Dietary'}

def encode_dietary_restrictions(dietary_str):
    if pd.isna(dietary_str):
        return set()
    restrictions = set(dietary_str.split(', '))
    if restrictions & veg_friendly:
        return {1}  # Veg
    elif restrictions & non_veg_friendly:
        return {3}  # Non-Veg
    return set()

Restaurants['encoded_dietaryrestrictions'] = Restaurants['dietaryrestrictions'].apply(encode_dietary_restrictions)

# Apply encoding
Restaurants['encoded_cuisines'] = Restaurants['cuisines'].apply(lambda x: {cuisine_encoder.get(c, 0) for c in x.split(', ')} if pd.notna(x) else set())
Hotels['encoded_amenities'] = Hotels['all_amenities'].apply(lambda x: {amenity_encoder.get(a, 0) for a in x.split(', ')} if pd.notna(x) else set())

# Encode user's food preference
food_preference_encoder = {'Veg': 1, 'Non-Veg': 3}
user_inputs['encoded_food_preference'] = user_inputs['food_preference'].map(food_preference_encoder)

# ---------------------------- #
# Step 4: Extract City Information
# ---------------------------- #
def extract_city(address):
    match = re.search(r'([A-Za-z ]+),? Sri Lanka', str(address))
    return match.group(1).strip() if match else None

Hotels['extracted_city'] = Hotels['address'].apply(extract_city)

# ---------------------------- #
# Step 5: ML-Based Matching Functions
# ---------------------------- #
def match_best_hotels(user_budget, user_destination, hotels_df):
    if user_destination not in allowed_destinations:
        return pd.DataFrame(columns=['name', 'rating'])
    hotels_in_city = hotels_df[hotels_df['extracted_city'] == user_destination]
    return hotels_in_city.sort_values(by=['rating', 'rankingposition'], ascending=[False, True])

def match_best_restaurants(user_cuisine_pref, user_food_pref, user_destination, restaurants_df):
    if user_destination not in allowed_destinations:
        return pd.DataFrame(columns=['name', 'cuisines'])
    restaurants_in_city = restaurants_df[restaurants_df['addressobj_city'] == user_destination].copy()
    return restaurants_in_city.sort_values(by='rating', ascending=False)

def match_best_attractions(user_budget, user_destination, attractions_df):
    if user_destination not in allowed_destinations:
        return pd.DataFrame(columns=['Name', 'Lowest_Price'])
    attractions_in_city = attractions_df[(attractions_df['City'] == user_destination) & (attractions_df['Lowest_Price'] <= user_budget)]
    return attractions_in_city.sort_values(by=['Rating', 'Ranking_Position'], ascending=[False, True])

# ---------------------------- #
# Step 6: Generate Itinerary
# ---------------------------- #

for index, user in user_inputs.iterrows():
    destinations = user['destination'].split(', ')
    num_days = user['number_of_days']

    # Handle multiple destinations: Assign 2 days per destination if num_days > 4
    if num_days >= 4:
        selected_destinations = destinations[:2]  # First two destinations
    else:
        selected_destinations = [destinations[0]]  # First destination

    # Print user details
    print(f"\n===== User {index + 1}: {user['name']} =====")
    print(f"Destinations: {', '.join(selected_destinations)}")
    print(f"Cuisine Preference: {user['cuisine_preference']}")
    print(f"Food Preference: {user['food_preference']}")
    print(f"Budget Per Day: {user['budget_per_day']}")

    for day in range(num_days):
        # Determine the current destination based on day and number of destinations
        current_destination = selected_destinations[min(day // 2, len(selected_destinations) - 1)]

        # Hotel recommendation: Change every 3 days if staying in one destination
        recommended_hotels = match_best_hotels(user['budget_per_day'], current_destination, Hotels)
        hotel = recommended_hotels.iloc[(day // 3) % len(recommended_hotels)] if not recommended_hotels.empty else None

        # Restaurant recommendations for breakfast, lunch, and dinner
        recommended_restaurants = match_best_restaurants(user['cuisine_preference'], user['food_preference'], current_destination, Restaurants)
        breakfast_restaurant = recommended_restaurants.iloc[day % len(recommended_restaurants)] if not recommended_restaurants.empty else None
        lunch_restaurant = recommended_restaurants.iloc[(day + 1) % len(recommended_restaurants)] if not recommended_restaurants.empty else None
        dinner_restaurant = recommended_restaurants.iloc[(day + 2) % len(recommended_restaurants)] if not recommended_restaurants.empty else None

        # Attraction recommendations
        recommended_attractions = match_best_attractions(user['budget_per_day'], current_destination, Attractions)
        attraction_1 = recommended_attractions.iloc[0] if not recommended_attractions.empty else None
        attraction_2 = recommended_attractions.iloc[1] if len(recommended_attractions) > 1 else None

        # Output the itinerary for the day
        print(f"\nDay {day + 1} - {current_destination}")
        print(f"Hotel: {hotel['name']} (Rating: {hotel['rating']})" if hotel is not None else "Hotel: Information Not Available")
        print(f"Breakfast: {breakfast_restaurant['name']} (Cuisines: {breakfast_restaurant['cuisines']}, Price: {breakfast_restaurant['pricelevel_lkr']})" if breakfast_restaurant is not None else "Breakfast: Information Not Available")
        print(f"Attraction 1: {attraction_1['Name']} (Lowest Price: {attraction_1['Lowest_Price']})" if attraction_1 is not None else "Attraction 1: Information Not Available")
        print(f"Lunch: {lunch_restaurant['name']} (Cuisines: {lunch_restaurant['cuisines']}, Price: {lunch_restaurant['pricelevel_lkr']})" if lunch_restaurant is not None else "Lunch: Information Not Available")
        print(f"Attraction 2: {attraction_2['Name']} (Lowest Price: {attraction_2['Lowest_Price']})" if attraction_2 is not None else "Attraction 2: Information Not Available")
        print(f"Dinner: {dinner_restaurant['name']} (Cuisines: {dinner_restaurant['cuisines']}, Price: {dinner_restaurant['pricelevel_lkr']})" if dinner_restaurant is not None else "Dinner: Information Not Available")
        print("Returning to Hotel\n")
        print("-" * 40)
# Out:
# Streaming output truncated to the last 5000 lines.
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: The Colonial Bistro & Lounge (Cuisines: Steakhouse, Bar, Barbecue, Asian, Pub, Sri Lankan, Beer restaurants, Price: 600)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Pepe's Rustic Italian (Cuisines: Italian, Bar, Pub, Price: 750)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: The Colonial Bistro & Lounge (Cuisines: Steakhouse, Bar, Barbecue, Asian, Pub, Sri Lankan, Beer restaurants, Price: 600)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: The Blizz Cafe (Cuisines: Italian, Chinese, Cafe, Asian, Soups, Price: 750)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast

# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: The Sackville (Cuisines: Bar, Price: 750)
# Attraction 1: DS Kumar Tuktuk Sightseeing in Nuwara Eliya (Lowest Price: No price mentioned)
# Lunch: Dhatha Home Foods (Cuisines: Asian, Sri Lankan, Price: 600)
# Attraction 2: nitwo tours (Lowest Price: No price mentioned)
# Dinner: The Skyline, Nuwara Eliya (Cuisines: International, Grill, Pub, Fusion, Wine Bar, Price: 600)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Dhatha Home Foods (Cuisines: Asian, Sri Lankan, Price: 600)
# Attraction 1: DS Kumar Tuktuk Sightseeing in Nuwara Eliya (Lowest Price: No price mentioned)
# Lunch: The Skyline, Nuwara Eliya (Cuisines: International, Grill, Pub, Fusion, Wine Bar, Price: 600)
# Attraction 2: nitwo tours (Lowest Price: No price mentioned)
# Dinner: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan, Price: 600)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 216: Subajini =====
# Destinations: Kandy, Dambulla
# Cuisine Preference: Sri Lankan, Indian, Italian
# Food Preference: Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Grand Sky Lounge (Cuisines: Bar, International, Pub, Dining bars, Price: 1200)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: Pepe's Rustic Italian (Cuisines: Italian, Bar, Pub, Price: 750)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: The Colonial Bistro & Lounge (Cuisines: Steakhouse, Bar, Barbecue, Asian, Pub, Sri Lankan, Beer restaurants, Price: 600)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Pepe's Rustic Italian (Cuisines: Italian, Bar, Pub, Price: 750)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: The Colonial Bistro & Lounge (Cuisines: Steakhouse, Bar, Barbecue, Asian, Pub, Sri Lankan, Beer restaurants, Price: 600)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: The Blizz Cafe (Cuisines: Italian, Chinese, Cafe, Asian, Soups, Price: 750)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Dambulla
# Hotel: Information Not Available
# Breakfast: Information Not Available
# Attraction 1: Information Not Available
# Lunch: Information Not Available
# Attraction 2: Information Not Available
# Dinner: Information Not Available
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Dambulla
# Hotel: Information Not Available
# Breakfast: Information Not Available
# Attraction 1: Information Not Available
# Lunch: Information Not Available
# Attraction 2: Information Not Available
# Dinner: Information Not Available
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Dambulla
# Hotel: Information Not Available
# Breakfast: Information Not Available
# Attraction 1: Information Not Available
# Lunch: Information Not Available
# Attraction 2: Information Not Available
# Dinner: Information Not Available
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 217: Atheeq Ahamed  =====
# Destinations: Kandy
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast:
- Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: The Colonial Bistro & Lounge (Cuisines: Steakhouse, Bar, Barbecue, Asian, Pub, Sri Lankan, Beer restaurants, Price: 600)
# Attraction 1: Aaliya Tours (Lowest Price: LKR 6,406.52)
# Lunch: The Blizz Cafe (Cuisines: Italian, Chinese, Cafe, Asian, Soups, Price: 750)
# Attraction 2: Yoga Reiki Meditation (Lowest Price: No price mentioned)
# Dinner: Lobster Arena (Cuisines: Italian, Chinese, Cafe, Seafood, Healthy, Price: 750)
# Returning to Hotel
#
# ----------------------------------------

# %%
# ---------------------------- #
# Step 1: Load Datasets
# ---------------------------- #

user_inputs = pd.read_excel('/content/drive/MyDrive/DSGP_ME/MergedDatasets/user_inputs_preprocessed.xlsx')
Hotels = pd.read_csv('/content/drive/MyDrive/DSGP_ME/MergedDatasets/ProcessedHotels.csv')
Restaurants = pd.read_csv('/content/drive/MyDrive/DSGP_ME/MergedDatasets/PreprocessedRestaurants.csv')
Attractions = pd.read_excel('/content/drive/MyDrive/DSGP_ME/MergedDatasets/attractions_preprocessed.xlsx')

# ---------------------------- #
# Step 2: Clean Column Names (Remove Spaces)
# ---------------------------- #
def clean_column_names(df):
    df.columns = [col.replace(' ', '_') for col in df.columns]
    return df

user_inputs = clean_column_names(user_inputs)
Hotels = clean_column_names(Hotels)
Restaurants = clean_column_names(Restaurants)
Attractions = clean_column_names(Attractions)

# ---------------------------- #
# Step 3: Encoding Destinations, Cuisines, Amenities, and Dietary Preferences
# ---------------------------- #

# Allowed destinations
allowed_destinations = {'Kandy', 'Ella', 'Colombo', 'Nuwara Eliya'}

# Encode destinations
all_destinations = set()
for dest in user_inputs['destination'].dropna():
    all_destinations.update(dest.split(', '))
destination_encoder = {dest: idx + 1 for idx, dest in enumerate(sorted(all_destinations)) if dest in allowed_destinations}

def encode_destinations(destination_str):
    return [destination_encoder.get(dest.strip()) for dest in destination_str.split(', ') if dest.strip() in destination_encoder]

user_inputs['encoded_destination'] = user_inputs['destination'].apply(encode_destinations)

# Encode cuisines in restaurants
all_cuisines = set()
for cuisines in Restaurants['cuisines'].dropna():
    all_cuisines.update(cuisines.split(', '))
cuisine_encoder = {cuisine: idx + 1 for idx, cuisine in enumerate(sorted(all_cuisines))}

# Encode amenities in hotels
all_amenities = set()
for amenities in Hotels['all_amenities'].dropna():
    all_amenities.update(amenities.split(', '))
amenity_encoder = {amenity: idx + 1 for idx, amenity in enumerate(sorted(all_amenities))}

# Encode dietary restrictions in restaurants
veg_friendly = {'Vegetarian friendly', 'Vegan options', 'Halal', 'Gluten free options'}
non_veg_friendly = {'No Special Dietary'}

def encode_dietary_restrictions(dietary_str):
    if pd.isna(dietary_str):
        return set()
    restrictions = set(dietary_str.split(', '))
    if restrictions & veg_friendly:
        return {1}  # Veg
    elif restrictions & non_veg_friendly:
        return {3}  # Non-Veg
    return set()

Restaurants['encoded_dietaryrestrictions'] = Restaurants['dietaryrestrictions'].apply(encode_dietary_restrictions)

# Apply encoding
Restaurants['encoded_cuisines'] = Restaurants['cuisines'].apply(lambda x: {cuisine_encoder[c] for c in x.split(', ')} if pd.notna(x) else set())
Hotels['encoded_amenities'] = Hotels['all_amenities'].apply(lambda x: {amenity_encoder[a] for a in x.split(', ')} if pd.notna(x) else set())

# Encode user's food preference
food_preference_encoder = {'Veg': 1, 'Non-Veg': 3}
user_inputs['encoded_food_preference'] = user_inputs['food_preference'].map(food_preference_encoder)

# ---------------------------- #
# Step 4: Extract City Information
# ---------------------------- #
def extract_city(address):
    match = re.search(r'([A-Za-z ]+),? Sri Lanka', str(address))
    return match.group(1).strip() if match else None

Hotels['extracted_city'] = Hotels['address'].apply(extract_city)

# ---------------------------- #
# Step 5: Clean Price Data (Attractions, Restaurants, Hotels, and User Budget)
# ---------------------------- #

# Function to clean the prices
def clean_price(price_str):
    if pd.isna(price_str):
        return None
    if 'No price mentioned' in price_str:
        return None
    price_str = price_str.replace('LKR', '').replace(',', '').strip()
    try:
        return float(price_str)
    except ValueError:
        return None

# Clean 'Lowest_Price' in Attractions
Attractions['Lowest_Price'] = Attractions['Lowest_Price'].apply(clean_price)

# Clean 'priceRange_LKR' in Hotels
Hotels['pricerange'] = Hotels['pricerange'].apply(clean_price)

# Clean 'budget_per_day' in user inputs
def clean_budget(budget_str):
    if pd.isna(budget_str):
        return None
    if 'Rs.' not in budget_str:
        return None
    budget_str = budget_str.replace('Rs.', '').replace(',', '').strip()
    if '-' in budget_str:
        lower, upper = budget_str.split(' - ')
        return (float(lower.strip()), float(upper.strip()))
    elif '+' in budget_str:
        return float(budget_str.replace('+', '').strip())
    return float(budget_str.strip())

user_inputs['cleaned_budget_per_day'] = user_inputs['budget_per_day'].apply(clean_budget)

# ---------------------------- #
# Step 6: Matching Functions (With Budget Constraints)
# ---------------------------- #

def match_best_hotels(user_budget, user_destination, hotels_df):
    hotels_in_city = hotels_df[hotels_df['extracted_city'] == user_destination]
    hotels_in_city = hotels_in_city[hotels_in_city['pricerange'] <= user_budget] if isinstance(user_budget, float) else hotels_in_city
    return hotels_in_city.sort_values(by=['rating', 'rankingposition'], ascending=[False, True])

def match_best_restaurants(user_cuisine_pref, user_food_pref, user_destination, restaurants_df, user_budget):
    if user_destination not in allowed_destinations:
        return pd.DataFrame()
    restaurants_in_city = restaurants_df[restaurants_df['addressobj_city'] == user_destination].copy()
    user_encoded_cuisines = {cuisine_encoder.get(c, 0) for c in user_cuisine_pref.split(', ') if c in cuisine_encoder}
    user_encoded_food_pref = food_preference_encoder.get(user_food_pref, 3)

    def calculate_match_score(row):
        cuisine_score = len(user_encoded_cuisines.intersection(row['encoded_cuisines']))
        dietary_score = int(user_encoded_food_pref in row['encoded_dietaryrestrictions'])
        return cuisine_score + dietary_score

    restaurants_in_city['match_score'] = restaurants_in_city.apply(calculate_match_score, axis=1)
    # Filter by budget
    restaurants_in_city = restaurants_in_city[restaurants_in_city['pricelevel_lkr'] <= user_budget] if isinstance(user_budget, float) else restaurants_in_city
    return restaurants_in_city.sort_values(by='match_score', ascending=False)

def match_best_attractions(user_budget, user_destination, attractions_df):
    if user_destination not in allowed_destinations:
        return pd.DataFrame()

    # Handle the case where the budget is a range (tuple)
    if isinstance(user_budget, tuple):
        min_budget, max_budget = user_budget
        attractions_in_city = attractions_df[(attractions_df['City'] == user_destination) &
                                             (attractions_df['Lowest_Price'] >= min_budget) &
                                             (attractions_df['Lowest_Price'] <= max_budget)]
    else:
        attractions_in_city = attractions_df[(attractions_df['City'] == user_destination) &
                                             (attractions_df['Lowest_Price'] <= user_budget)]

    return attractions_in_city.sort_values(by=['Rating', 'Ranking_Position'], ascending=[False, True])


# ---------------------------- #
# Step 7: Generate Itinerary (With Budget Constraints)
# ---------------------------- #

for index, user in user_inputs.iterrows():
    destinations = user['destination'].split(', ')
    num_days = user['number_of_days']
    selected_destinations = destinations[:2] if num_days >= 4 else [destinations[0]]

    print(f"\n===== User {index + 1}: {user['name']} =====")
    print(f"Destination: {', '.join(selected_destinations)}")
    print(f"Cuisine Preference: {user['cuisine_preference']}")
    print(f"Food Preference: {user['food_preference']}")
    print(f"Budget Per Day: {user['budget_per_day']}")

    for day in range(num_days):
        current_destination = selected_destinations[min(day // 2, len(selected_destinations) - 1)]
        recommended_hotels = match_best_hotels(user['cleaned_budget_per_day'], current_destination, Hotels)
        recommended_restaurants = match_best_restaurants(user['cuisine_preference'], user['food_preference'], current_destination, Restaurants, user['cleaned_budget_per_day'])
        recommended_attractions = match_best_attractions(user['cleaned_budget_per_day'], current_destination, Attractions)

        if recommended_hotels.empty:
          print("No hotels found for the selected destination and budget.")
          continue  # Skip to the next user

        if recommended_restaurants.empty:
          print(f"No restaurants found for the selected destination on Day {day + 1}.")
          continue  # Skip to the next day

        if recommended_attractions.empty:
          print(f"No attractions found for the selected destination on Day {day + 1}.")
          continue  # Skip to the next day

        # Now you can safely proceed to the original logic
        hotel = recommended_hotels.iloc[(day // 3) % len(recommended_hotels)]

        breakfast_restaurant = recommended_restaurants.iloc[day % len(recommended_restaurants)]
        attraction_1 = recommended_attractions.iloc[day % len(recommended_attractions)]
        lunch_restaurant = recommended_restaurants.iloc[(day + 1) % len(recommended_restaurants)]
        attraction_2 = recommended_attractions.iloc[(day + 1) % len(recommended_attractions)]
        dinner_restaurant = recommended_restaurants.iloc[(day + 2) % len(recommended_restaurants)]

        print(f"\nDay {day + 1} - {current_destination}")
        print(f"Hotel: {hotel['name']} (Rating: {hotel['rating']})")
        print(f"Breakfast: {breakfast_restaurant['name']} (Cuisines: {breakfast_restaurant['cuisines']})")
        print(f"Attraction 1: {attraction_1['Name']} (Lowest Price: {attraction_1['Lowest_Price']})")
        print(f"Lunch: {lunch_restaurant['name']} (Cuisines: {lunch_restaurant['cuisines']})")
        print(f"Attraction 2: {attraction_2['Name']} (Lowest Price: {attraction_2['Lowest_Price']})")
        print(f"Dinner: {dinner_restaurant['name']} (Cuisines: {dinner_restaurant['cuisines']})")
        print("Returning to Hotel\n")
        print("-" * 40)
# Out:
# Streaming output truncated to the last 5000 lines.
# Attraction 1: Lover's Leap Falls (Lowest Price: 7611.24)
# Lunch: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: La Cottage Boutique Hotel & Restuarant (Cuisines: Chinese, Indian, European, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 150: Daham  =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan, Indian, Italian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 1: Lover's Leap Falls (Lowest Price: 7611.24)
# Lunch: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Pedro Tea Factory (Lowest Price: 7611.24)
# Lunch: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Dinner: Oishi Cafeteria (Cuisines: Chinese, Indian, Barbecue, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Lunch: Oishi Cafeteria (Cuisines: Chinese, Indian, Barbecue, Asian, Sri Lankan)
# Attraction 2: Lover's Leap Falls (Lowest Price: 7611.24)
# Dinner: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 151: Satkunalingam V =====
# Destination: Ella, Dambulla
# Cuisine Preference: Sri Lankan, Indian, Thai
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
#
# ===== User 152: Vinotharaj Shambavi =====
# Destination: Kandy, Ella
# Cuisine Preference: Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Dosa Cafe Ella (Cuisines: Italian, Indian, European, Asian, Central Asian)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Singhe restaurant (Cuisines: Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Singhe restaurant (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Jungle Cafe (Cuisines: Chinese, Indian)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: Singhe restaurant (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Jungle Cafe (Cuisines: Chinese, Indian)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Hide Ella Cafe & Restaurant (Cuisines: Italian, Indian, International, Asian, Healthy, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Jungle Cafe (Cuisines: Chinese, Indian)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Hide Ella Cafe & Restaurant (Cuisines: Italian, Indian, International, Asian, Healthy, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Ellarch (Cuisines: Chinese, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 153: Chethiya senarath =====
# Destination: Nuwara Eliya
# Cuisine Preference: Italian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Royal Wok Restaurant (Cuisines: Italian, French, Chinese, Cafe)
# Attraction 1: Nuwara Eliya Roots (Lowest Price: 1463.7)
# Lunch: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Horton Plains National Park (Lowest Price: 1829.63)
# Dinner: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Horton Plains National Park (Lowest Price: 1829.63)
# Lunch: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 2: Gregory Lake (Lowest Price: 1829.63)
# Dinner: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 1: Gregory Lake (Lowest Price: 1829.63)
# Lunch: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Dinner: Salmiya (Cuisines: Italian, Pizza)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Lunch: Salmiya (Cuisines: Italian, Pizza)
# Attraction 2: Victoria Park of Nuwara Eliya (Lowest Price: 1610.07)
# Dinner: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Salmiya (Cuisines: Italian, Pizza)
# Attraction 1: Victoria Park of Nuwara Eliya (Lowest Price: 1610.07)
# Lunch: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 2: Nuwara Eliya Roots (Lowest Price: 1463.7)
# Dinner: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 1: Nuwara Eliya Roots (Lowest Price: 1463.7)
# Lunch: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Attraction 2: Horton Plains National Park (Lowest Price: 1829.63)
# Dinner: Restaurant Guru (Cuisines: Southwestern, Eastern European)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: National Holiday Resort (Rating: 3.5)
# Breakfast: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Attraction 1: Horton Plains National Park (Lowest Price: 1829.63)
# Lunch: Restaurant Guru (Cuisines: Southwestern, Eastern European)
# Attraction 2: Gregory Lake (Lowest Price: 1829.63)
# Dinner: The Skyline - Rooftop Lounge & Bar (Cuisines: Chinese, Indian, European, Asian, Indigenous)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 154: Mithushan =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Nature life guest inn Ella Sri Lanka (Cuisines: Italian, American, Indian, Filipino, Asian, Sri Lankan)
# Attraction 1: Ravana Ella Falls (Lowest Price: 1820.03)
# Lunch: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Little Adam's Peak View Point (Lowest Price: 1820.03)
# Dinner: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Little Adam's Peak View Point (Lowest Price: 1820.03)
# Lunch: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 2: Nine Arches Bridge (Lowest Price: 1456.03)
# Dinner: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 155: Amsan Naheswaran  =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 156: Sowmiya Ranjan  =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Natural View Point & Restaurant (Cuisines: Chinese, Indian, Southwestern, European, Asian, Sri Lankan)
# Attraction 1: Nuwara Eliya Roots (Lowest Price: 1463.7)
# Lunch: Cafe Cinnomon (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Horton Plains National Park (Lowest Price: 1829.63)
# Dinner: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Cafe Cinnomon (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Horton Plains National Park (Lowest Price: 1829.63)
# Lunch: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Gregory Lake (Lowest Price: 1829.63)
# Dinner: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Gregory Lake (Lowest Price: 1829.63)
# Lunch: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Dinner: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 157: Dulen =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Natural View Point & Restaurant (Cuisines: Chinese, Indian, Southwestern, European, Asian, Sri Lankan)
# Attraction 1: Lover's Leap Falls (Lowest Price: 7611.24)
# Lunch: Cafe Cinnomon (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day

# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: National Holiday Resort (Rating: 3.5)
# Breakfast: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Lover's Leap Falls (Lowest Price: 7611.24)
# Lunch: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: La Cottage Boutique Hotel & Restuarant (Cuisines: Chinese, Indian, European, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 158: Seniru  =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Chinese, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 159: Harindu =====
# Destination: Ella
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
#
# Day 1 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Ella Chophouse (Cuisines: Asian, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Tiki Bar Ella (Cuisines: Bar, Pub, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Senkin Restaurant (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Tiki Bar Ella (Cuisines: Bar, Pub, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Senkin Restaurant (Cuisines: Asian, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Lakshmi's Cookery Class (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Senkin Restaurant (Cuisines: Asian, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Lakshmi's Cookery Class (Cuisines: Asian, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Ramesh Restaurant (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 160: Methuli Fernando =====
# Destination: Kandy
# Cuisine Preference: Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 161: Theebi =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Cafe KOI Coffee (Cuisines: Cafe, European, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Oak Ray Bakers (Cuisines: Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Oak Ray Bakers (Cuisines: Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast:
sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 1: Devon Falls (Lowest Price: 17704.92)
# Lunch: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Attraction 2: Shri Bhakta Hanuman Temple (Lowest Price: 17175.06)
# Dinner: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Attraction 1: Shri Bhakta Hanuman Temple (Lowest Price: 17175.06)
# Lunch: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: St Clair's Falls (Lowest Price: 17704.92)
# Dinner: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: St Clair's Falls (Lowest Price: 17704.92)
# Lunch: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Sita Temple (Lowest Price: 17472.34)
# Dinner: Dhatha Home Foods (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: National Holiday Resort (Rating: 3.5)
# Breakfast: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Sita Temple (Lowest Price: 17472.34)
# Lunch: Dhatha Home Foods (Cuisines: Asian, Sri Lankan)
# Attraction 2: Devon Falls (Lowest Price: 17704.92)
# Dinner: Tck 6685 Restaurant (Cuisines: International, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 163: Venuki =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Chinese, Italian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Cocoba Restaurant (Cuisines: Italian, Chinese, Bar, Cafe, Asian, Pub, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: The Chef Corner & Vip Lounge By Sugath (Cuisines: Italian, Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Cocoba Restaurant (Cuisines: Italian, Chinese, Bar, Cafe, Asian, Pub, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: The Chef Corner & Vip Lounge By Sugath (Cuisines: Italian, Chinese, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: MARINATE (Cuisines: Italian, Chinese, American, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
# No attractions found for the selected destination on Day 3.
# No attractions found for the selected destination on Day 4.
# No attractions found for the selected destination on Day 5.
#
# ===== User 164: MRS .Kavitha Skantharuban  =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
# No attractions found for the selected destination on Day 4.
# No attractions found for the selected destination on Day 5.
# No attractions found for the selected destination on Day 6.
# No attractions found for the selected destination on Day 7.
#
# ===== User 165: Dilini Nawarathna =====
# Destination: Kandy
# Cuisine Preference: Chinese
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: High Tide Seafood Restaurant (Cuisines: Chinese, Seafood, Asian, Fusion, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Kandy Catering Service Viyana Cafe & Family Restaurant (Cuisines: Chinese, American, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Kandy Catering Service Viyana Cafe & Family Restaurant (Cuisines: Chinese, American, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: The Hideout Cafe Kandy (Cuisines: Chinese, American, Indian, Cafe, Asian, Mongolian)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Kandy Catering Service Viyana Cafe & Family Restaurant (Cuisines: Chinese, American, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: The Hideout Cafe Kandy (Cuisines: Chinese, American, Indian, Cafe, Asian, Mongolian)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Cocoba Restaurant (Cuisines: Italian, Chinese, Bar, Cafe, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 166: Sajini Kariyawasam  =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 167: Kavindu  =====
# Destination: Ella, Dambulla
# Cuisine Preference: Sri Lankan, Indian, Italian, Western, Mexican
# Food Preference: Veg
# Budget Per Day: Rs. 25000+
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
#
# ===== User 168: Revathy poovendranthan  =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast
- Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Ella's Edge Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Ella's Edge Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Golden Cabin Ella (Cuisines: Chinese, American, European, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: Ella's Edge Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Golden Cabin Ella (Cuisines: Chinese, American, European, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: Golden Cabin Ella (Cuisines: Chinese, American, European, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Ice Mango Ella (Cuisines: Indian, Seafood, European, Asian, Street Food, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Ice Mango Ella (Cuisines: Indian, Seafood, European, Asian, Street Food, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Rawan Adams Resturent (Cuisines: Chinese, European, Asian, Central European, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 171: Rajkumer Hemachandran🎵🎵🎵 =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
# No attractions found for the selected destination on Day 4.
#
# ===== User 172: Akith Nanayakkara  =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Western, Thai
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 173: Tharanica =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Nature life guest inn Ella Sri Lanka (Cuisines: Italian, American, Indian, Filipino, Asian, Sri Lankan)
# Attraction 1: Ravana Ella Falls (Lowest Price: 1820.03)
# Lunch: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Little Adam's Peak View Point (Lowest Price: 1820.03)
# Dinner: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Little Adam's Peak View Point (Lowest Price: 1820.03)
# Lunch: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 2: Nine Arches Bridge (Lowest Price: 1456.03)
# Dinner: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 1: Nine Arches Bridge (Lowest Price: 1456.03)
# Lunch: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Ravana Ella Falls (Lowest Price: 1820.03)
# Dinner: Cafe Ridge (Cuisines: Indian, Southwestern, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Ravana Ella Falls (Lowest Price: 1820.03)
# Lunch: Cafe Ridge (Cuisines: Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Little Adam's Peak View Point (Lowest Price: 1820.03)
# Dinner: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Cafe Ridge (Cuisines: Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Little Adam's Peak View Point (Lowest Price: 1820.03)
# Lunch: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 2: Nine Arches Bridge (Lowest Price: 1456.03)
# Dinner: Hide Ella Cafe & Restaurant (Cuisines: Italian, Indian, International, Asian, Healthy, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 174: T.suthaji =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 175: Lumini devdunu =====
# Destination: Ella
# Cuisine Preference: Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 176: Surakkitha Galappaththi =====
# Destination: Kandy, Ella
# Cuisine Preference: Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 20500 - Rs. 24500
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
# No attractions found for the selected destination on Day 4.
# No attractions found for the selected destination on Day 5.
# No attractions found for the selected destination on Day 6.
# No attractions found for the selected destination on Day 7.
#
# ===== User 177: Deepana isuruwan =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast
asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 1: Sita Temple (Lowest Price: 17472.34)
# Lunch: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 2: Devon Falls (Lowest Price: 17704.92)
# Dinner: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 1: Devon Falls (Lowest Price: 17704.92)
# Lunch: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Attraction 2: Shri Bhakta Hanuman Temple (Lowest Price: 17175.06)
# Dinner: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Attraction 1: Shri Bhakta Hanuman Temple (Lowest Price: 17175.06)
# Lunch: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: St Clair's Falls (Lowest Price: 17704.92)
# Dinner: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: St Clair's Falls (Lowest Price: 17704.92)
# Lunch: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Sita Temple (Lowest Price: 17472.34)
# Dinner: Dhatha Home Foods (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: National Holiday Resort (Rating: 3.5)
# Breakfast: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Sita Temple (Lowest Price: 17472.34)
# Lunch: Dhatha Home Foods (Cuisines: Asian, Sri Lankan)
# Attraction 2: Devon Falls (Lowest Price: 17704.92)
# Dinner: Tck 6685 Restaurant (Cuisines: International, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 179: W.S.Tharika  =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Italian, Western
# Food Preference: Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Lion Brand Coffee & Bakery (Cuisines: Italian, Mexican, American, Cafe, Asian, Thai, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Kurumbunkz (Cuisines: Italian, American, Asian, Australian, Indonesian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Mystery Meat (Cuisines: Italian, International, Asian, Korean, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Kurumbunkz (Cuisines: Italian, American, Asian, Australian, Indonesian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Mystery Meat (Cuisines: Italian, International, Asian, Korean, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: The Pub (Cuisines: Bar, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
# No attractions found for the selected destination on Day 3.
# No attractions found for the selected destination on Day 4.
#
# ===== User 180: Ushani =====
# Destination: Ella
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
# No attractions found for the selected destination on Day 4.
# No attractions found for the selected destination on Day 5.
#
# ===== User 181: Vaasuthan vigneswaran  =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan
# Food Preference: Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Chill Ramboda (Cuisines: Asian, Sri Lankan)
# Attraction 1: Nuwara Eliya Roots (Lowest Price: 1463.7)
# ...
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
# No attractions found for the selected destination on Day 4.
# No attractions found for the selected destination on Day 5.
#
# ===== User 309: Nethma Gunarathne =====
# Destination: Ella
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 310: demini waidyanatha =====
# Destination: Ella
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 311: Tharusha Liyanagama =====
# Destination: Ella
# Cuisine Preference: Chinese
# Food Preference: Non-Veg
# Budget Per Day: Rs. 20500 - Rs. 24500
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
#
# ===== User 312: Kavishan =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Attraction 1: Sita Temple (Lowest Price: 14637.0)
# Lunch: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 2: Bluefield Tea Gardens (Lowest Price: 14344.26)
# Dinner: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 1: Bluefield Tea Gardens (Lowest Price: 14344.26)
# Lunch: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 2: Shanthipura View Point (Lowest Price: 11709.6)
# Dinner: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 1: Shanthipura View Point (Lowest Price: 11709.6)
# Lunch: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 2: Sita Temple (Lowest Price: 14637.0)
# Dinner: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 313: Yehan  =====
# Destination: Ella
# Cuisine Preference: Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 314: Gayandi =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Western, Thai
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 315: Benito Jeyaratnam  =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai
# Food Preference: Non-Veg
# Budget Per Day: Rs. 20500 - Rs. 24500
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
# No attractions found for the selected destination on Day 4.
# No attractions found for the selected destination on Day 5.
# No attractions found for the selected destination on Day 6.
# No attractions found for the selected destination on Day 7.
#
# ===== User 316: Kishoby Sriranjan =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 317: Ashvin Hemachandran  =====
# Destination: Colombo
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 25000+
#
# Day 1 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: Kava Island Bar (Cuisines: Bar, Asian, Pub, Polynesian, Sri Lankan)
# Attraction 1: Blue Lanka Tours (Lowest Price: 20093.19)
# Lunch: Amma Nissa (Cuisines: Asian, Fusion, Sri Lankan)
# Attraction 2: Blue Lanka Tours (Lowest Price: 20093.19)
# Dinner: Ketam House (Cuisines: Seafood, Barbecue, Asian, Malaysian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: Amma Nissa (Cuisines: Asian, Fusion, Sri Lankan)
# Attraction 1: Blue Lanka Tours (Lowest Price: 20093.19)
# Lunch: Ketam House (Cuisines: Seafood, Barbecue, Asian, Malaysian, Sri Lankan)
# Attraction 2: Less Taxi (Lowest Price: 58.24)
# Dinner: The Nosh (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: Ketam House (Cuisines: Seafood, Barbecue, Asian, Malaysian, Sri Lankan)
# Attraction 1: Less Taxi (Lowest Price: 58.24)
# Lunch: The Nosh (Cuisines: Asian, Sri Lankan)
# Attraction 2: Colombo Cooking Class (Lowest Price: 145.6)
# Dinner: Harbour Room (Cuisines: Bar, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Colombo
# Hotel: Groove House (Rating: 4.5)
# Breakfast: The Nosh (Cuisines: Asian, Sri Lankan)
# Attraction 1: Colombo Cooking Class (Lowest Price: 145.6)
# Lunch: Harbour Room (Cuisines: Bar, Asian, Pub, Sri Lankan)
# Attraction 2: Sri Lankan Tuk Tuk Safari (Lowest Price: 101.92)
# Dinner: The Fat Crab (Cuisines: Seafood, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Colombo
# Hotel: Groove House (Rating: 4.5)
# Breakfast: Harbour Room (Cuisines: Bar, Asian, Pub, Sri Lankan)
# Attraction 1: Sri Lankan Tuk Tuk Safari (Lowest Price: 101.92)
# Lunch: The Fat Crab (Cuisines: Seafood, Sri Lankan)
# Attraction 2: Sri Lanka Personal Tour Drivers (Lowest Price: 946.42)
# Dinner: The Joint Pub And Grill (Cuisines: Bar, International, Pub, Fusion, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Colombo
# Hotel: Groove House (Rating: 4.5)
# Breakfast: The Fat Crab (Cuisines: Seafood, Sri Lankan)
# Attraction 1: Sri Lanka Personal Tour Drivers (Lowest Price: 946.42)
# Lunch: The Joint Pub And Grill (Cuisines: Bar, International, Pub, Fusion, Sri Lankan)
# Attraction 2: Drivers in Sri Lanka (Lowest Price: 203.84)
# Dinner: Curry by Lotus (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: The Joint Pub And Grill (Cuisines: Bar, International, Pub, Fusion, Sri Lankan)
# Attraction 1: Drivers in Sri Lanka (Lowest Price: 203.84)
# Lunch: Curry by Lotus (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Red Dot Tours Lanka (Lowest Price: 174.72)
# Dinner: The Poolside Bar and Terrace (Cuisines: Bar, International, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 318: S.D.Perera =====
# Destination: Ella, Nuwara Eliya
# Cuisine Preference: Sri Lankan, Chinese
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 1: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Lunch: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Lover's Leap Falls (Lowest Price: 7611.24)
# Dinner: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Lover's Leap Falls (Lowest Price: 7611.24)
# Lunch: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Pedro Tea Factory (Lowest Price: 7611.24)
# Lunch: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Dinner: Gregory Green Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Lunch: Gregory Green Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Lover's Leap Falls (Lowest Price: 7611.24)
# Dinner: Natural View Point & Restaurant (Cuisines: Chinese, Indian, Southwestern, European, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: National Holiday Resort (Rating: 3.5)
# Breakfast: Gregory Green Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Lover's Leap Falls (Lowest Price: 7611.24)
# Lunch: Natural View Point & Restaurant (Cuisines: Chinese, Indian, Southwestern, European, Asian, Sri Lankan)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: Club Trout (Cuisines: Chinese, Dutch, Southwestern, European, Asian, Middle Eastern, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 319: Sanuki Waduge  =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Chinese, Italian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Pub Ceylon Ella (Cuisines: Italian, International, Asian, Grill, Healthy, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Rawan Adams Resturent (Cuisines: Chinese, European, Asian, Central European, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: Pub Ceylon Ella (Cuisines: Italian, International, Asian, Grill, Healthy, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Rawan Adams Resturent (Cuisines: Chinese, European, Asian, Central European, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Ella
# Hotel: La Ella Breeze (Rating: 4.0)
# Breakfast: Rawan Adams Resturent (Cuisines: Chinese, European, Asian, Central European, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Avocado Cafe Ella (Cuisines: Italian, Mexican, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 320: Seniru Dilmith =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Italian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.
#
# ===== User 321: Sahi =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Attraction 1: Nuwara Eliya Roots (Lowest Price: 1463.7)
# Lunch: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 2: Horton Plains National Park (Lowest Price: 1829.63)
# Dinner: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 1: Horton Plains National Park (Lowest Price: 1829.63)
# Lunch: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 2: Gregory Lake (Lowest Price: 1829.63)
# Dinner: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Woodnest Sithula Garden Resort (Rating: 5)
# Breakfast: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 1: Gregory Lake (Lowest Price: 1829.63)
# Lunch: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 2: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Dinner: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 322: Neelia maha oluwa =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Veg
# Budget Per Day: Rs. 25000+
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
#
# ===== User 323: Manahari  =====
# Destination: Kandy
# Cuisine Preference: Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for the selected destination on Day 1.
# No attractions found for the selected destination on Day 2.
# No attractions found for the selected destination on Day 3.

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

# ---------------------------- #
# Step 1: Load Datasets
# ---------------------------- #

user_inputs = pd.read_excel('/content/drive/MyDrive/DSGP_ME/MergedDatasets/user_inputs_preprocessed.xlsx')
Hotels = pd.read_csv('/content/drive/MyDrive/DSGP_ME/MergedDatasets/ProcessedHotels.csv')
Restaurants = pd.read_csv('/content/drive/MyDrive/DSGP_ME/MergedDatasets/PreprocessedRestaurants.csv')
Attractions = pd.read_excel('/content/drive/MyDrive/DSGP_ME/MergedDatasets/attractions_preprocessed.xlsx')

# ---------------------------- #
# Step 2: Clean Column Names (Remove Spaces)
# ---------------------------- #
def clean_column_names(df):
    df.columns = [col.replace(' ', '_') for col in df.columns]
    return df

user_inputs = clean_column_names(user_inputs)
Hotels = clean_column_names(Hotels)
Restaurants = clean_column_names(Restaurants)
Attractions = clean_column_names(Attractions)

# ---------------------------- #
# Step 3: Encoding Destinations, Cuisines, Amenities, and Dietary Preferences
# ---------------------------- #

# Allowed destinations
allowed_destinations = {'Kandy', 'Ella', 'Colombo', 'Nuwara Eliya'}

# Encode destinations
all_destinations = set()
for dest in user_inputs['destination'].dropna():
    all_destinations.update(dest.split(', '))
destination_encoder = {dest: idx + 1 for idx, dest in enumerate(sorted(all_destinations)) if dest in allowed_destinations}

def encode_destinations(destination_str):
    return [destination_encoder.get(dest.strip()) for dest in destination_str.split(', ') if dest.strip() in destination_encoder]

user_inputs['encoded_destination'] = user_inputs['destination'].apply(encode_destinations)

# Encode cuisines in restaurants
all_cuisines = set()
for cuisines in Restaurants['cuisines'].dropna():
    all_cuisines.update(cuisines.split(', '))
cuisine_encoder = {cuisine: idx + 1 for idx, cuisine in enumerate(sorted(all_cuisines))}

# Encode amenities in hotels
all_amenities = set()
for amenities in Hotels['all_amenities'].dropna():
    all_amenities.update(amenities.split(', '))
amenity_encoder = {amenity: idx + 1 for idx, amenity in enumerate(sorted(all_amenities))}

# Encode dietary restrictions in restaurants
veg_friendly = {'Vegetarian friendly', 'Vegan options', 'Halal', 'Gluten free options'}
non_veg_friendly = {'No Special Dietary'}

def encode_dietary_restrictions(dietary_str):
    if pd.isna(dietary_str):
        return set()
    restrictions = set(dietary_str.split(', '))
    if restrictions & veg_friendly:
        return {1}  # Veg
    elif restrictions & non_veg_friendly:
        return {3}  # Non-Veg
    return set()

Restaurants['encoded_dietaryrestrictions'] = Restaurants['dietaryrestrictions'].apply(encode_dietary_restrictions)

# Apply encoding
Restaurants['encoded_cuisines'] = Restaurants['cuisines'].apply(lambda x: {cuisine_encoder[c] for c in x.split(', ')} if pd.notna(x) else set())
Hotels['encoded_amenities'] = Hotels['all_amenities'].apply(lambda x: {amenity_encoder[a] for a in x.split(', ')} if pd.notna(x) else set())

# Encode user's food preference
food_preference_encoder = {'Veg': 1, 'Non-Veg': 3}
user_inputs['encoded_food_preference'] = user_inputs['food_preference'].map(food_preference_encoder)

# ---------------------------- #
# Step 4: Extract City Information
# ---------------------------- #
def extract_city(address):
    match = re.search(r'([A-Za-z ]+),? Sri Lanka', str(address))
    return match.group(1).strip() if match else None

Hotels['extracted_city'] = Hotels['address'].apply(extract_city)

# ---------------------------- #
# Step 5: Clean Price Data (Attractions, Restaurants, Hotels, and User Budget)
# ---------------------------- #

# Function to clean the prices
def clean_price(price_str):
    if pd.isna(price_str):
        return None
    if 'No price mentioned' in price_str:
        return None
    price_str = price_str.replace('LKR', '').replace(',', '').strip()
    try:
        return float(price_str)
    except ValueError:
        return None

# Clean 'Lowest_Price' in Attractions
Attractions['Lowest_Price'] = Attractions['Lowest_Price'].apply(clean_price)

# Clean 'priceRange_LKR' in Hotels
Hotels['pricerange'] = Hotels['pricerange'].apply(clean_price)

# Clean 'budget_per_day' in user inputs
def clean_budget(budget_str):
    if pd.isna(budget_str):
        return None
    if 'Rs.' not in budget_str:
        return None
    budget_str = budget_str.replace('Rs.', '').replace(',', '').strip()
    if '-' in budget_str:
        lower, upper = budget_str.split(' - ')
        return (float(lower.strip()), float(upper.strip()))
    elif '+' in budget_str:
        return float(budget_str.replace('+', '').strip())
    return float(budget_str.strip())

user_inputs['cleaned_budget_per_day'] = user_inputs['budget_per_day'].apply(clean_budget)

# ---------------------------- #
# Step 6: Matching Functions (With Budget Constraints)
# ---------------------------- #

def match_best_hotels(user_budget, user_destination, hotels_df):
    hotels_in_city = hotels_df[hotels_df['extracted_city'] == user_destination]
    hotels_in_city = hotels_in_city[hotels_in_city['pricerange'] <= user_budget] if isinstance(user_budget, float) else hotels_in_city
    return hotels_in_city.sort_values(by=['rating', 'rankingposition'], ascending=[False, True])

def match_best_restaurants(user_cuisine_pref, user_food_pref, user_destination, restaurants_df, user_budget):
    if user_destination not in allowed_destinations:
        return pd.DataFrame()
    restaurants_in_city = restaurants_df[restaurants_df['addressobj_city'] == user_destination].copy()
    user_encoded_cuisines = {cuisine_encoder.get(c, 0) for c in user_cuisine_pref.split(', ') if c in cuisine_encoder}
    user_encoded_food_pref = food_preference_encoder.get(user_food_pref, 3)

    def calculate_match_score(row):
        cuisine_score = len(user_encoded_cuisines.intersection(row['encoded_cuisines']))
        dietary_score = int(user_encoded_food_pref in row['encoded_dietaryrestrictions'])
        return cuisine_score + dietary_score

    restaurants_in_city['match_score'] = restaurants_in_city.apply(calculate_match_score, axis=1)
    # Filter by budget
    restaurants_in_city = restaurants_in_city[restaurants_in_city['pricelevel_lkr'] <= user_budget] if isinstance(user_budget, float) else restaurants_in_city
    return restaurants_in_city.sort_values(by='match_score', ascending=False)

def match_best_attractions(user_budget, user_destination, attractions_df):
    if user_destination not in allowed_destinations:
        return pd.DataFrame()

    # Handle the case where the budget is a range (tuple)
    if isinstance(user_budget, tuple):
        min_budget, max_budget = user_budget
        attractions_in_city = attractions_df[(attractions_df['City'] == user_destination) &
                                             (attractions_df['Lowest_Price'] >= min_budget) &
                                             (attractions_df['Lowest_Price'] <= max_budget)]
    else:
        attractions_in_city = attractions_df[(attractions_df['City'] == user_destination) &
                                             (attractions_df['Lowest_Price'] <= user_budget)]

    return attractions_in_city.sort_values(by=['Rating', 'Ranking_Position'], ascending=[False, True])

# ---------------------------- #
# Step 8: Feature Engineering for Content-Based Filtering
# ---------------------------- #

def replace_not_rated(value, median_value):
    return median_value if value == 'not rated' else value

def replace_no_ranking(value, median_value):
    return median_value if value == 'no ranking' else value

# Convert 'not rated' and 'no ranking' values to NaN, compute median, and replace
Attractions['Rating'] = pd.to_numeric(Attractions['Rating'], errors='coerce')
median_attraction_rating = Attractions['Rating'].median()
Attractions['Rating'].fillna(median_attraction_rating, inplace=True)

Hotels['rating'] = pd.to_numeric(Hotels['rating'], errors='coerce')
median_hotel_rating = Hotels['rating'].median()
Hotels['rating'].fillna(median_hotel_rating, inplace=True)

Attractions['Ranking_Position'] = pd.to_numeric(Attractions['Ranking_Position'], errors='coerce')
median_attraction_ranking = Attractions['Ranking_Position'].median()
Attractions['Ranking_Position'].fillna(median_attraction_ranking, inplace=True)

Hotels['rankingposition'] = pd.to_numeric(Hotels['rankingposition'], errors='coerce')
median_hotel_ranking = Hotels['rankingposition'].median()
Hotels['rankingposition'].fillna(median_hotel_ranking, inplace=True)

# Normalize and transform data for similarity calculations
def create_feature_matrix(df, feature_columns):
    scaler = StandardScaler()
    feature_matrix = scaler.fit_transform(df[feature_columns].fillna(0))
    return feature_matrix

# Feature columns for hotels and attractions
hotel_features = ['rating', 'rankingposition', 'pricerange']
attraction_features = ['Rating', 'Ranking_Position', 'Lowest_Price']

Hotels['feature_matrix'] = list(create_feature_matrix(Hotels, hotel_features))
Attractions['feature_matrix'] = list(create_feature_matrix(Attractions, attraction_features))

# ---------------------------- #
# Step 9: Content-Based Filtering for Hotels
# ---------------------------- #

def recommend_similar_hotels(hotel_df, user_budget, user_destination, top_n=5):
    hotels_in_city = hotel_df[hotel_df['extracted_city'] == user_destination].copy()
    if isinstance(user_budget, float):
        hotels_in_city = hotels_in_city[hotels_in_city['pricerange'] <= user_budget]

    if hotels_in_city.empty:
        return pd.DataFrame()

    feature_matrix = np.stack(hotels_in_city['feature_matrix'].values)
    similarity_matrix = cosine_similarity(feature_matrix)

    # Rank hotels based on similarity to all other hotels
    avg_similarity = similarity_matrix.mean(axis=1)
    hotels_in_city.loc[:, 'similarity_score'] = avg_similarity
    return hotels_in_city.sort_values(by=['similarity_score', 'rating', 'rankingposition'], ascending=[False, False, True]).head(top_n)

# ---------------------------- #
# Step 10: Content-Based Filtering for Attractions
# ---------------------------- #

def recommend_similar_attractions(attraction_df, user_budget, user_destination, top_n=5):
    attractions_in_city = attraction_df[attraction_df['City'] == user_destination].copy()

    if isinstance(user_budget, tuple):
        min_budget, max_budget = user_budget
        attractions_in_city = attractions_in_city[(attractions_in_city['Lowest_Price'] >= min_budget) & (attractions_in_city['Lowest_Price'] <= max_budget)]
    elif isinstance(user_budget, float):
        attractions_in_city = attractions_in_city[attractions_in_city['Lowest_Price'] <= user_budget]

    if attractions_in_city.empty:
        return pd.DataFrame()

    feature_matrix = np.stack(attractions_in_city['feature_matrix'].values)
    similarity_matrix = cosine_similarity(feature_matrix)

    # Rank attractions based on similarity
    avg_similarity = similarity_matrix.mean(axis=1)
    attractions_in_city.loc[:, 'similarity_score'] = avg_similarity
    return attractions_in_city.sort_values(by=['similarity_score', 'Rating', 'Ranking_Position'], ascending=[False, False, True]).head(top_n)

# ---------------------------- #
# Step 11: Integrating Enhanced Recommendations into Itinerary
# ---------------------------- #

for index, user in user_inputs.iterrows():
    destinations = user['destination'].split(', ')
    num_days = user['number_of_days']
    selected_destinations = destinations[:2] if num_days >= 4 else [destinations[0]]

    print(f"\n===== User {index + 1}: {user['name']} =====")
    print(f"Destination: {', '.join(selected_destinations)}")
    print(f"Cuisine Preference: {user['cuisine_preference']}")
    print(f"Food Preference: {user['food_preference']}")
    print(f"Budget Per Day: {user['budget_per_day']}")

    hotel_stay_counter = 0  # Track how long user stays in a hotel
    current_hotel = None  # Store the current hotel

    for day in range(num_days):
        current_destination = selected_destinations[min(day // 2, len(selected_destinations) - 1)]

        if hotel_stay_counter == 0 or hotel_stay_counter >= 3:
            recommended_hotels = recommend_similar_hotels(Hotels, user['cleaned_budget_per_day'], current_destination)
            if not recommended_hotels.empty:
                current_hotel = recommended_hotels.iloc[0]
                hotel_stay_counter = 1  # Reset the counter after changing hotel
            else:
                print("No hotels found for the selected destination and budget.")
                continue
        else:
            hotel_stay_counter += 1  # Increment stay counter if continuing in the same hotel

        recommended_attractions = recommend_similar_attractions(Attractions, user['cleaned_budget_per_day'], current_destination)
        recommended_restaurants = match_best_restaurants(user['cuisine_preference'], user['food_preference'], current_destination, Restaurants, user['cleaned_budget_per_day'])

        if recommended_restaurants.empty:
            print(f"No restaurants found for {current_destination} on Day {day + 1}.")
            continue

        if recommended_attractions.empty:
            print(f"No attractions found for {current_destination} on Day {day + 1}.")
            continue

        breakfast_restaurant = recommended_restaurants.iloc[day % len(recommended_restaurants)]
        attraction_1 = recommended_attractions.iloc[day % len(recommended_attractions)]
        lunch_restaurant = recommended_restaurants.iloc[(day + 1) % len(recommended_restaurants)]
        attraction_2 = recommended_attractions.iloc[(day + 1) % len(recommended_attractions)]
        dinner_restaurant = recommended_restaurants.iloc[(day + 2) % len(recommended_restaurants)]

        print(f"\nDay {day + 1} - {current_destination}")
        print(f"Hotel: {current_hotel['name']} (Rating: {current_hotel['rating']})")
        print(f"Breakfast: {breakfast_restaurant['name']} (Cuisines: {breakfast_restaurant['cuisines']})")
        print(f"Attraction 1: {attraction_1['Name']} (Lowest Price: {attraction_1['Lowest_Price']})")
        print(f"Lunch: {lunch_restaurant['name']} (Cuisines: {lunch_restaurant['cuisines']})")
        print(f"Attraction 2: {attraction_2['Name']} (Lowest Price: {attraction_2['Lowest_Price']})")
        print(f"Dinner: {dinner_restaurant['name']} (Cuisines: {dinner_restaurant['cuisines']})")
        print("Returning to Hotel\n")
        print("-" * 40)
# Out:
# <ipython-input-9-92df09ff1b7d>:183: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Attractions['Rating'].fillna(median_attraction_rating, inplace=True)
# <ipython-input-9-92df09ff1b7d>:187: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Hotels['rating'].fillna(median_hotel_rating, inplace=True)
# <ipython-input-9-92df09ff1b7d>:191: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Attractions['Ranking_Position'].fillna(median_attraction_ranking, inplace=True)
# <ipython-input-9-92df09ff1b7d>:195: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Hotels['rankingposition'].fillna(median_hotel_ranking, inplace=True)
# Streaming output truncated to the last 5000 lines.
# Attraction 1: Pedro Tea Factory (Lowest Price: 7611.24)
# Lunch: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Lover's Leap Falls (Lowest Price: 7611.24)
# Dinner: La Cottage Boutique Hotel & Restuarant (Cuisines: Chinese, Indian, European, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 150: Daham  =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan, Indian, Italian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 1: Pedro Tea Factory (Lowest Price: 7611.24)
# Lunch: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Lover's Leap Falls (Lowest Price: 7611.24)
# Dinner: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Lover's Leap Falls (Lowest Price: 7611.24)
# Lunch: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Dinner: Oishi Cafeteria (Cuisines: Chinese, Indian, Barbecue, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Lunch: Oishi Cafeteria (Cuisines: Chinese, Indian, Barbecue, Asian, Sri Lankan)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 151: Satkunalingam V =====
# Destination: Ella, Dambulla
# Cuisine Preference: Sri Lankan, Indian, Thai
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for Ella on Day 1.
# No attractions found for Ella on Day 2.
# No restaurants found for Dambulla on Day 3.
# No hotels found for the selected destination and budget.
#
# ===== User 152: Vinotharaj Shambavi =====
# Destination: Kandy, Ella
# Cuisine Preference: Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
#
# Day 3 - Ella
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Dosa Cafe Ella (Cuisines: Italian, Indian, European, Asian, Central Asian)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Singhe restaurant (Cuisines: Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Singhe restaurant (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Jungle Cafe (Cuisines: Chinese, Indian)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Singhe restaurant (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Jungle Cafe (Cuisines: Chinese, Indian)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Hide Ella Cafe & Restaurant (Cuisines: Italian, Indian, International, Asian, Healthy, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Jungle Cafe (Cuisines: Chinese, Indian)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Hide Ella Cafe & Restaurant (Cuisines: Italian, Indian, International, Asian, Healthy, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Ellarch (Cuisines: Chinese, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 153: Chethiya senarath =====
# Destination: Nuwara Eliya
# Cuisine Preference: Italian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Royal Wok Restaurant (Cuisines: Italian, French, Chinese, Cafe)
# Attraction 1: Horton Plains National Park (Lowest Price: 1829.63)
# Lunch: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Gregory Lake (Lowest Price: 1829.63)
# Dinner: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Gregory Lake (Lowest Price: 1829.63)
# Lunch: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 2: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Dinner: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 1: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Lunch: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Victoria Park of Nuwara Eliya (Lowest Price: 1610.07)
# Dinner: Salmiya (Cuisines: Italian, Pizza)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Victoria Park of Nuwara Eliya (Lowest Price: 1610.07)
# Lunch: Salmiya (Cuisines: Italian, Pizza)
# Attraction 2: Nuwara Eliya Roots (Lowest Price: 1463.7)
# Dinner: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Salmiya (Cuisines: Italian, Pizza)
# Attraction 1: Nuwara Eliya Roots (Lowest Price: 1463.7)
# Lunch: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 2: Horton Plains National Park (Lowest Price: 1829.63)
# Dinner: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 1: Horton Plains National Park (Lowest Price: 1829.63)
# Lunch: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Attraction 2: Gregory Lake (Lowest Price: 1829.63)
# Dinner: Restaurant Guru (Cuisines: Southwestern, Eastern European)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Attraction 1: Gregory Lake (Lowest Price: 1829.63)
# Lunch: Restaurant Guru (Cuisines: Southwestern, Eastern European)
# Attraction 2: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Dinner: The Skyline - Rooftop Lounge & Bar (Cuisines: Chinese, Indian, European, Asian, Indigenous)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 154: Mithushan =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
#
# Day 3 - Ella
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Nature life guest inn Ella Sri Lanka (Cuisines: Italian, American, Indian, Filipino, Asian, Sri Lankan)
# Attraction 1: Ravana Ella Falls (Lowest Price: 1820.03)
# Lunch: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Nine Arches Bridge (Lowest Price: 1456.03)
# Dinner: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Nine Arches Bridge (Lowest Price: 1456.03)
# Lunch: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 2: Little Adam's Peak View Point (Lowest Price: 1820.03)
# Dinner: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 155: Amsan Naheswaran  =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
#
# ===== User 156: Sowmiya Ranjan  =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Natural View Point & Restaurant (Cuisines: Chinese, Indian, Southwestern, European, Asian, Sri Lankan)
# Attraction 1: Horton Plains National Park (Lowest Price: 1829.63)
# Lunch: Cafe Cinnomon (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Gregory Lake (Lowest Price: 1829.63)
# Dinner: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Cafe Cinnomon (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Gregory Lake (Lowest Price: 1829.63)
# Lunch: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Dinner: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Lunch: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Victoria Park of Nuwara Eliya (Lowest Price: 1610.07)
# Dinner: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 157: Dulen =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Natural View Point & Restaurant (Cuisines: Chinese, Indian, Southwestern, European, Asian, Sri Lankan)
# Attraction 1: Pedro Tea Factory (Lowest Price: 7611.24)
# Lunch: Cafe Cinnomon (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Lover's Leap Falls (Lowest Price: 7611.24)
# Dinner: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Cafe Cinnomon (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Lover's Leap Falls (Lowest Price: 7611.24)
# Lunch: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Dinner: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Midky Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan, Arabic)
# Attraction 1: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Lunch: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Pedro Tea Factory (Lowest Price: 7611.24)
# Lunch: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 2: Lover's Leap Falls (Lowest Price: 7611.24)
# Dinner: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 1: Lover's Leap Falls (Lowest Price: 7611.24)
# Lunch: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Dinner: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Lunch: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Pedro Tea Factory (Lowest Price: 7611.24)
# Lunch: Fusion Grill (Cuisines: Italian, Indian, Asian, Sri Lankan, Arabic)
# Attraction 2: Lover's Leap Falls (Lowest Price: 7611.24)
# Dinner: La Cottage Boutique Hotel & Restuarant (Cuisines: Chinese, Indian, European, Asian, Sri Lankan, Arabic)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 158: Seniru  =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Chinese, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
#
# ===== User 159: Harindu =====
# Destination: Ella
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
#
# Day 1 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Ella Chophouse (Cuisines: Asian, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Tiki Bar Ella (Cuisines: Bar, Pub, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Senkin Restaurant (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Tiki Bar Ella (Cuisines: Bar, Pub, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Senkin Restaurant (Cuisines: Asian, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Lakshmi's Cookery Class (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Senkin Restaurant (Cuisines: Asian, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Lakshmi's Cookery Class (Cuisines: Asian, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Ramesh Restaurant (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 160: Methuli Fernando =====
# Destination: Kandy
# Cuisine Preference: Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
#
# ===== User 161: Theebi =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Cafe KOI Coffee (Cuisines: Cafe, European, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Oak Ray Bakers (Cuisines: Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Oak Ray Bakers (Cuisines: Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Dosa Kallu (Cuisines: Indian, Fast Food, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Kandy Supreme Hotel (Cuisines: Chinese, European, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Kandy Supreme Hotel (Cuisines: Chinese, European, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Mymomo (Cuisines: Chinese, Cafe, Asian, Korean, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Kandy Supreme Hotel (Cuisines: Chinese, European, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Mymomo (Cuisines: Chinese, Cafe, Asian, Korean, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Yummy Choice (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Mymomo (Cuisines: Chinese, Cafe, Asian, Korean, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Yummy Choice (Cuisines: Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Sthree Cafe (Cuisines: Cafe, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Yummy Choice (Cuisines: Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Sthree Cafe (Cuisines: Cafe, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 162: Ravi Seevanayagam =====
# Destination: Ella, Nuwara Eliya
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
#
# Day 1 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Ella Chophouse (Cuisines: Asian, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Tiki Bar Ella (Cuisines: Bar, Pub, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Senkin Restaurant (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Tiki Bar Ella (Cuisines: Bar, Pub, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Senkin Restaurant (Cuisines: Asian, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Lakshmi's Cookery Class (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 1: Sita Temple (Lowest Price: 17472.34)
# Lunch: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 2: Shri Bhakta Hanuman Temple (Lowest Price: 17175.06)
# Dinner: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 1: Shri Bhakta Hanuman Temple (Lowest Price: 17175.06)
# Lunch: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Attraction 2: St Clair's Falls (Lowest Price: 17704.92)
# Dinner: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Attraction 1: St Clair's Falls (Lowest Price: 17704.92)
# Lunch: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Devon Falls (Lowest Price: 17704.92)
# Dinner: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Devon Falls (Lowest Price: 17704.92)
# Lunch: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Sita Temple (Lowest Price: 17472.34)
# Dinner: Dhatha Home Foods (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Sita Temple (Lowest Price: 17472.34)
# Lunch: Dhatha Home Foods (Cuisines: Asian, Sri Lankan)
# Attraction 2: Shri Bhakta Hanuman Temple (Lowest Price: 17175.06)
# Dinner: Tck 6685 Restaurant (Cuisines: International, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 163: Venuki =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Chinese, Italian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Cocoba Restaurant (Cuisines: Italian, Chinese, Bar, Cafe, Asian, Pub, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: The Chef Corner & Vip Lounge By Sugath (Cuisines: Italian, Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Cocoba Restaurant (Cuisines: Italian, Chinese, Bar, Cafe, Asian, Pub, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: The Chef Corner & Vip Lounge By Sugath (Cuisines: Italian, Chinese, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: MARINATE (Cuisines: Italian, Chinese, American, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
# No attractions found for Ella on Day 3.
# No attractions found for Ella on Day 4.
# No attractions found for Ella on Day 5.
#
# ===== User 164: MRS .Kavitha Skantharuban  =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
# No attractions found for Kandy on Day 4.
# No attractions found for Kandy on Day 5.
# No attractions found for Kandy on Day 6.
# No attractions found for Kandy on Day 7.
#
# ===== User 165: Dilini Nawarathna =====
# Destination: Kandy
# Cuisine Preference: Chinese
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: High Tide Seafood Restaurant (Cuisines: Chinese, Seafood, Asian, Fusion, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Castle Lane Cafe & Restaurant (Cuisines: Chinese, American, Indian, Asian, Thai, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Lyon's Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Kandy Catering Service Viyana Cafe & Family Restaurant (Cuisines: Chinese, American, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Timber Cabin Restaurant & Lounge (Cuisines: Italian, Chinese, Cafe, Asian, Indonesian, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Kandy Catering Service Viyana Cafe & Family Restaurant (Cuisines: Chinese, American, Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: The Hideout Cafe Kandy (Cuisines: Chinese, American, Indian, Cafe, Asian, Mongolian)
# Returning to Hotel
#
# ----------------------------------------
#
# Day
asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 169: Sathi  =====
# Destination: Ella, Dambulla
# Cuisine Preference: Sri Lankan, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 25000+
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
#
# ===== User 170: Sarvo =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian, Chinese
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
#
# Day 3 - Ella
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Ella's Edge Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Ella's Edge Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Golden Cabin Ella (Cuisines: Chinese, American, European, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Ella's Edge Restaurant (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Golden Cabin Ella (Cuisines: Chinese, American, European, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Golden Cabin Ella (Cuisines: Chinese, American, European, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Ice Mango Ella (Cuisines: Indian, Seafood, European, Asian, Street Food, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 1: Demodara Loop (Lowest Price: 11648.22)
# Lunch: Ice Mango Ella (Cuisines: Indian, Seafood, European, Asian, Street Food, Sri Lankan)
# Attraction 2: Demodara Loop (Lowest Price: 11648.22)
# Dinner: Rawan Adams Resturent (Cuisines: Chinese, European, Asian, Central European, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 171: Rajkumer Hemachandran🎵🎵🎵 =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
# No attractions found for Kandy on Day 4.
#
# ===== User 172: Akith Nanayakkara  =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Western, Thai
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
#
# ===== User 173: Tharanica =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
#
# Day 3 - Ella
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Nature life guest inn Ella Sri Lanka (Cuisines: Italian, American, Indian, Filipino, Asian, Sri Lankan)
# Attraction 1: Ravana Ella Falls (Lowest Price: 1820.03)
# Lunch: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Nine Arches Bridge (Lowest Price: 1456.03)
# Dinner: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The Pastry House (Cuisines: Italian, Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Nine Arches Bridge (Lowest Price: 1456.03)
# Lunch: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 2: Little Adam's Peak View Point (Lowest Price: 1820.03)
# Dinner: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Tip Top Sky Bar Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 1: Little Adam's Peak View Point (Lowest Price: 1820.03)
# Lunch: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Ravana Ella Falls (Lowest Price: 1820.03)
# Dinner: Cafe Ridge (Cuisines: Indian, Southwestern, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Ravana Ella Falls (Lowest Price: 1820.03)
# Lunch: Cafe Ridge (Cuisines: Indian, Southwestern, Asian, Sri Lankan)
# Attraction 2: Nine Arches Bridge (Lowest Price: 1456.03)
# Dinner: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Cafe Ridge (Cuisines: Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Nine Arches Bridge (Lowest Price: 1456.03)
# Lunch: Hotel 4you Ella (Cuisines: American, Indian, Asian, Sri Lankan)
# Attraction 2: Little Adam's Peak View Point (Lowest Price: 1820.03)
# Dinner: Hide Ella Cafe & Restaurant (Cuisines: Italian, Indian, International, Asian, Healthy, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 174: T.suthaji =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
#
# ===== User 175: Lumini devdunu =====
# Destination: Ella
# Cuisine Preference: Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for Ella on Day 1.
# No attractions found for Ella on Day 2.
# No attractions found for Ella on Day 3.
#
# ===== User 176: Surakkitha Galappaththi =====
# Destination: Kandy, Ella
# Cuisine Preference: Chinese, Italian, Western, Thai, Mexican
asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 1: Sita Temple (Lowest Price: 17472.34)
# Lunch: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 2: Shri Bhakta Hanuman Temple (Lowest Price: 17175.06)
# Dinner: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 1: Shri Bhakta Hanuman Temple (Lowest Price: 17175.06)
# Lunch: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Attraction 2: St Clair's Falls (Lowest Price: 17704.92)
# Dinner: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Attraction 1: St Clair's Falls (Lowest Price: 17704.92)
# Lunch: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Devon Falls (Lowest Price: 17704.92)
# Dinner: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Devon Falls (Lowest Price: 17704.92)
# Lunch: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 2: Sita Temple (Lowest Price: 17472.34)
# Dinner: Dhatha Home Foods (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Royal Pearl Hills (pvt) Ltd (Cuisines: Indian, Asian, Sri Lankan)
# Attraction 1: Sita Temple (Lowest Price: 17472.34)
# Lunch: Dhatha Home Foods (Cuisines: Asian, Sri Lankan)
# Attraction 2: Shri Bhakta Hanuman Temple (Lowest Price: 17175.06)
# Dinner: Tck 6685 Restaurant (Cuisines: International, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 179: W.S.Tharika  =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Italian, Western
# Food Preference: Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
#
# Day 1 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Lion Brand Coffee & Bakery (Cuisines: Italian, Mexican, American, Cafe, Asian, Thai, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Kurumbunkz (Cuisines: Italian, American, Asian, Australian, Indonesian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# ...
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Mymomo (Cuisines: Chinese, Cafe, Asian, Korean, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Yummy Choice (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Kandy
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: Mymomo (Cuisines: Chinese, Cafe, Asian, Korean, Sri Lankan)
# Attraction 1: Aaliya Tours (Lowest Price: 6406.52)
# Lunch: Yummy Choice (Cuisines: Asian, Sri Lankan)
# Attraction 2: Aaliya Tours (Lowest Price: 6406.52)
# Dinner: Sthree Cafe (Cuisines: Cafe, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 308: Danishya Shanmuganathan  =====
# Destination: Ella
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for Ella on Day 1.
# No attractions found for Ella on Day 2.
# No attractions found for Ella on Day 3.
# No attractions found for Ella on Day 4.
# No attractions found for Ella on Day 5.
#
# ===== User 309: Nethma Gunarathne =====
# Destination: Ella
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for Ella on Day 1.
# No attractions found for Ella on Day 2.
# No attractions found for Ella on Day 3.
#
# ===== User 310: demini waidyanatha =====
# Destination: Ella
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for Ella on Day 1.
# No attractions found for Ella on Day 2.
# No attractions found for Ella on Day 3.
#
# ===== User 311: Tharusha Liyanagama =====
# Destination: Ella
# Cuisine Preference: Chinese
# Food Preference: Non-Veg
# Budget Per Day: Rs. 20500 - Rs. 24500
# No attractions found for Ella on Day 1.
# No attractions found for Ella on Day 2.
#
# ===== User 312: Kavishan =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
#
# Day 1 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Attraction 1: Bluefield Tea Gardens (Lowest Price: 14344.26)
# Lunch: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 2: Sita Temple (Lowest Price: 14637.0)
# Dinner: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 1: Sita Temple (Lowest Price: 14637.0)
# Lunch: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 2: Shanthipura View Point (Lowest Price: 11709.6)
# Dinner: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 1: Shanthipura View Point (Lowest Price: 11709.6)
# Lunch: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 2: Bluefield Tea Gardens (Lowest Price: 14344.26)
# Dinner: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 313: Yehan  =====
# Destination: Ella
# Cuisine Preference: Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for Ella on Day 1.
# No attractions found for Ella on Day 2.
# No attractions found for Ella on Day 3.
#
# ===== User 314: Gayandi =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Western, Thai
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
#
# ===== User 315: Benito Jeyaratnam  =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai
# Food Preference: Non-Veg
# Budget Per Day: Rs. 20500 - Rs. 24500
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Ella on Day 3.
# No attractions found for Ella on Day 4.
# No attractions found for Ella on Day 5.
# No attractions found for Ella on Day 6.
# No attractions found for Ella on Day 7.
#
# ===== User 316: Kishoby Sriranjan =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 10500 - Rs. 15000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
#
# ===== User 317: Ashvin Hemachandran  =====
# Destination: Colombo
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 25000+
#
# Day 1 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: Kava Island Bar (Cuisines: Bar, Asian, Pub, Polynesian, Sri Lankan)
# Attraction 1: ZRI Adventures (Lowest Price: 2912.06)
# Lunch: Amma Nissa (Cuisines: Asian, Fusion, Sri Lankan)
# Attraction 2: Go Ceylon Tours (Lowest Price: 1790.91)
# Dinner: Ketam House (Cuisines: Seafood, Barbecue, Asian, Malaysian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: Amma Nissa (Cuisines: Asian, Fusion, Sri Lankan)
# Attraction 1: Go Ceylon Tours (Lowest Price: 1790.91)
# Lunch: Ketam House (Cuisines: Seafood, Barbecue, Asian, Malaysian, Sri Lankan)
# Attraction 2: Travceylon Leisure (Lowest Price: 2620.85)
# Dinner: The Nosh (Cuisines: Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: Ketam House (Cuisines: Seafood, Barbecue, Asian, Malaysian, Sri Lankan)
# Attraction 1: Travceylon Leisure (Lowest Price: 2620.85)
# Lunch: The Nosh (Cuisines: Asian, Sri Lankan)
# Attraction 2: Vacation Lanka Tours (Lowest Price: 1456.03)
# Dinner: Harbour Room (Cuisines: Bar, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: The Nosh (Cuisines: Asian, Sri Lankan)
# Attraction 1: Vacation Lanka Tours (Lowest Price: 1456.03)
# Lunch: Harbour Room (Cuisines: Bar, Asian, Pub, Sri Lankan)
# Attraction 2: Thara Lanka Tours (Lowest Price: 3995.34)
# Dinner: The Fat Crab (Cuisines: Seafood, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: Harbour Room (Cuisines: Bar, Asian, Pub, Sri Lankan)
# Attraction 1: Thara Lanka Tours (Lowest Price: 3995.34)
# Lunch: The Fat Crab (Cuisines: Seafood, Sri Lankan)
# Attraction 2: ZRI Adventures (Lowest Price: 2912.06)
# Dinner: The Joint Pub And Grill (Cuisines: Bar, International, Pub, Fusion, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: The Fat Crab (Cuisines: Seafood, Sri Lankan)
# Attraction 1: ZRI Adventures (Lowest Price: 2912.06)
# Lunch: The Joint Pub And Grill (Cuisines: Bar, International, Pub, Fusion, Sri Lankan)
# Attraction 2: Go Ceylon Tours (Lowest Price: 1790.91)
# Dinner: Curry by Lotus (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Colombo
# Hotel: Nivasa (Rating: 4.5)
# Breakfast: The Joint Pub And Grill (Cuisines: Bar, International, Pub, Fusion, Sri Lankan)
# Attraction 1: Go Ceylon Tours (Lowest Price: 1790.91)
# Lunch: Curry by Lotus (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Travceylon Leisure (Lowest Price: 2620.85)
# Dinner: The Poolside Bar and Terrace (Cuisines: Bar, International, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 318: S.D.Perera =====
# Destination: Ella, Nuwara Eliya
# Cuisine Preference: Sri Lankan, Chinese
# Food Preference: Non-Veg
# Budget Per Day: Rs. 5100 - Rs. 10000
# No attractions found for Ella on Day 1.
# No attractions found for Ella on Day 2.
#
# Day 3 - Nuwara Eliya
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Lemon Lounge Restaurant And Pub (Cuisines: Italian, Chinese, American, Asian, Pub, Sri Lankan)
# Attraction 1: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Lunch: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: sinha Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Pedro Tea Factory (Lowest Price: 7611.24)
# Lunch: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Lover's Leap Falls (Lowest Price: 7611.24)
# Dinner: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Eleven 2 Eleven Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Lover's Leap Falls (Lowest Price: 7611.24)
# Lunch: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Dinner: Gregory Green Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 6 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Hotel Sun Inn & Restaurant (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 1: Post Office Nuwara Eliya (Lowest Price: 7611.24)
# Lunch: Gregory Green Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 2: Pedro Tea Factory (Lowest Price: 7611.24)
# Dinner: Natural View Point & Restaurant (Cuisines: Chinese, Indian, Southwestern, European, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 7 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Gregory Green Restaurant (Cuisines: Chinese, Asian, Sri Lankan)
# Attraction 1: Pedro Tea Factory (Lowest Price: 7611.24)
# Lunch: Natural View Point & Restaurant (Cuisines: Chinese, Indian, Southwestern, European, Asian, Sri Lankan)
# Attraction 2: Lover's Leap Falls (Lowest Price: 7611.24)
# Dinner: Club Trout (Cuisines: Chinese, Dutch, Southwestern, European, Asian, Middle Eastern, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 319: Sanuki Waduge  =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Chinese, Italian, Western
# Food Preference: Non-Veg
# Budget Per Day: Rs. 15500 - Rs. 20000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
#
# Day 3 - Ella
# Hotel: Railway Retiring Rooms Kandy (Rating: 3.5)
# Breakfast: The Apple Inn Restaurant (Cuisines: Chinese, Indian, Southwestern, Asian, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Pub Ceylon Ella (Cuisines: Italian, International, Asian, Grill, Healthy, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Rawan Adams Resturent (Cuisines: Chinese, European, Asian, Central European, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 4 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Pub Ceylon Ella (Cuisines: Italian, International, Asian, Grill, Healthy, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: Rawan Adams Resturent (Cuisines: Chinese, European, Asian, Central European, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 5 - Ella
# Hotel: Rawana Holiday Resort (Rating: 4.0)
# Breakfast: Rawan Adams Resturent (Cuisines: Chinese, European, Asian, Central European, Sri Lankan)
# Attraction 1: Ravana's Cave (Lowest Price: 16307.51)
# Lunch: The True Food Restaurant Ella (Cuisines: Chinese, Indian, Asian, Sri Lankan)
# Attraction 2: Ravana's Cave (Lowest Price: 16307.51)
# Dinner: Avocado Cafe Ella (Cuisines: Italian, Mexican, Asian, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 320: Seniru Dilmith =====
# Destination: Kandy
# Cuisine Preference: Sri Lankan, Indian, Italian
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
#
# ===== User 321: Sahi =====
# Destination: Nuwara Eliya
# Cuisine Preference: Sri Lankan
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
#
# Day 1 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Frostbite (Cuisines: Italian, Cafe, International, Asian, Sri Lankan)
# Attraction 1: Horton Plains National Park (Lowest Price: 1829.63)
# Lunch: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 2: Gregory Lake (Lowest Price: 1829.63)
# Dinner: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 2 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Pub Nuwara Eliya (Cuisines: Italian, French, Indian, Irish, Brew Pub, Bar, Cafe, Seafood, Fast Food, European, Asian, Pub, Wine Bar, Street Food, Swedish, Sri Lankan, Arabic, Fruit parlours, Dining bars, Beer restaurants)
# Attraction 1: Gregory Lake (Lowest Price: 1829.63)
# Lunch: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 2: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Dinner: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# Day 3 - Nuwara Eliya
# Hotel: Serenus Boutique Villa (Rating: 4.5)
# Breakfast: Hills Restaurant (Cuisines: Chinese, Indian, Asian, Singaporean, South American, Central American, Sri Lankan)
# Attraction 1: Damro Labookellie Tea Centre and Tea Garden (Lowest Price: 1829.63)
# Lunch: Palladium Restaurant (Cuisines: Pizza, Asian, Pub, Sri Lankan)
# Attraction 2: Victoria Park of Nuwara Eliya (Lowest Price: 1610.07)
# Dinner: Collingwood Hotel Restaurant (Cuisines: Sri Lankan)
# Returning to Hotel
#
# ----------------------------------------
#
# ===== User 322: Neelia maha oluwa =====
# Destination: Kandy, Ella
# Cuisine Preference: Sri Lankan, Indian, Chinese, Italian, Western, Thai, Mexican
# Food Preference: Veg
# Budget Per Day: Rs. 25000+
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
# No hotels found for the selected destination and budget.
#
# ===== User 323: Manahari  =====
# Destination: Kandy
# Cuisine Preference: Chinese, Italian, Western, Thai, Mexican
# Food Preference: Non-Veg
# Budget Per Day: Rs. 1000 - Rs. 5000
# No attractions found for Kandy on Day 1.
# No attractions found for Kandy on Day 2.
# No attractions found for Kandy on Day 3.
